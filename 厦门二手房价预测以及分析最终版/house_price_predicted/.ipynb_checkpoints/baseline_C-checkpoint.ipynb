# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import json
import os
import seaborn as sns
from geopy.distance import geodesic
from tqdm import tqdm
from xgboost import XGBRegressor
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler, MaxAbsScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
import warnings
warnings.filterwarnings('ignore')

# %%
sns.set_style("darkgrid")  # 图表风格
plt.rcParams['font.sans-serif']=['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False  # 用来正常显示负号

# %%
#数据存储路径
dataPath='./data/lianjia.xls'

# %%
#读取数据
data=pd.read_excel(dataPath)

# %% [markdown]
# # 数据预处理

# %%
#数据预览
data.head()
# Out:
#    ID    name address model     area direct perfect      floor  year  type  \
# 0   1    厦罐宿舍    禾祥西路  1室1厅  46.89平米      南      简装   高楼层(共7层)  1998    板楼
# 1   2    万寿北路     文园路  2室1厅  48.67平米      南      简装   低楼层(共7层)  1991    板楼
# 2   3    菁英公馆    翔安新城   NaN      NaN    NaN     NaN        NaN   NaN   NaN
# 3   4  南湖中祥大厦      槟榔  1室1厅  45.08平米   东南 南      精装  低楼层(共31层)  2007  板塔结合
# 4   5    王子广场   海沧生活区  1室1厅   34.2平米      南      简装  中楼层(共25层)  2011  板塔结合
#
#    total         unit      traffic
# 0  216.0  单价46066元/平米      近1号线文灶站
# 1  310.0  单价63695元/平米     近1号线将军祠站
# 2   45.0  单价12163元/平米          NaN
# 3  308.0  单价68323元/平米    近2号线体育中心站
# 4   99.4  单价29065元/平米  近2号线海沧行政中心站

# %%
# 发现存在缺失信息较多的房源，接下来进行筛选后删除
# 删除总价及单价均为空的数据
data.drop(index=data[(data['total'].isnull()) & (data['unit'].isnull())].index, inplace=True)
# 筛选并保留缺失比例小于50
tmp_df = data[['name', 'address', 'model', 'area', 'direct', 'perfect', 'floor','year','type', 'traffic']]
rows_null = tmp_df.isnull().sum(axis=1) / len(tmp_df.columns)
data = data.loc[rows_null < 0.5, :]

# %%
from urllib.request import urlopen,quote

# %% [markdown]
# ### 1.调用百度地理-逆地理api，使用小区名进行经纬度转换

# %%
# 转换函数
def getlnglat(adress):
    url = 'http://api.map.baidu.com/geocoder/v2/?address='
    output = 'json'
    ak = 'NncC2ROHKWGoZ158tfqdziUprQW81ins'
    add = quote(adress)#使用quote进行编码 为了防止中文乱码
    url2 = url + add + '&output=' + output + '&ak=' + ak
    req = urlopen(url2)
    res = req.read().decode()
    temp = json.loads(res)
    return temp

# %%
# 地址前加上厦门进行范围限制，防止跨省同名小区覆盖
data['name'] = '厦门' + data['name']
# 开辟新列表用来存储转换结果
geo_list = np.zeros((data.shape[0], 2))

# %%
if 1:
    dim = data.shape
    [row,col] = dim  #获取行列数
    cnt = 0
    for i in tqdm(data.values):
        try:
            b = i[0]  #首列的小区名
            geo_list[cnt][0] = getlnglat(b)['result']['location']['lng']#获取经度并写入
            geo_list[cnt][1] = getlnglat(b)['result']['location']['lat']#获取纬度并写入
        except:
            print("第{}条数据转换出错 ".format(cnt))
            geo_list[cnt][0] = 0
            geo_list[cnt][1] = 0
        cnt += 1
    # api转换错误的少数小区手动转化
    geo_list[605][0], geo_list[605][1] = 118.098148, 24.446382
    geo_list[5737][0], geo_list[5737][1] = 118.24771, 24.601405
    geo_list[6555][0], geo_list[6555][1] = 118.087447, 24.501763
    geo_list[7790][0], geo_list[7790][1] = 118.087447, 24.501763
    geo_list[8311][0], geo_list[8311][1] = 118.098148, 24.446382
    data['经度'] = geo_list[:, 0]
    data['纬度'] = geo_list[:, 1]
    data.to_csv("./data/geo_trans.csv")
       
else:
    data = pd.read_csv("./data/geo_trans.csv")
# Out:
#   0%|                                                                                        | 0/17058 [00:00<?, ?it/s]
# 第0条数据转换出错
# 第1条数据转换出错
# 第2条数据转换出错
# 第3条数据转换出错
# 第4条数据转换出错
# 第5条数据转换出错
# 第6条数据转换出错
# 第7条数据转换出错
# 第8条数据转换出错
# 第9条数据转换出错
# 第10条数据转换出错
# 第11条数据转换出错
# 第12条数据转换出错
# 第13条数据转换出错
# 第14条数据转换出错
# 第15条数据转换出错
# 第16条数据转换出错
# 第17条数据转换出错
# 第18条数据转换出错
# 第19条数据转换出错
# 第20条数据转换出错
# 第21条数据转换出错
# 第22条数据转换出错
# 第23条数据转换出错
# 第24条数据转换出错
# 第25条数据转换出错
# 第26条数据转换出错
# 第27条数据转换出错
# 第28条数据转换出错
# 第29条数据转换出错
# 第30条数据转换出错
# 第31条数据转换出错
# 第32条数据转换出错
# 第33条数据转换出错
# 第34条数据转换出错
# 第35条数据转换出错
# 第36条数据转换出错
# 第37条数据转换出错
# 第38条数据转换出错
# 第39条数据转换出错
# 第40条数据转换出错
# 第41条数据转换出错
# 第42条数据转换出错
# 第43条数据转换出错
# 第44条数据转换出错
# 第45条数据转换出错
# 第46条数据转换出错
# 第47条数据转换出错
#   0%|▏                                                                             | 48/17058 [00:00<00:36, 471.86it/s]
# 第48条数据转换出错
# 第49条数据转换出错
# 第50条数据转换出错
# 第51条数据转换出错
# 第52条数据转换出错
# 第53条数据转换出错
# 第54条数据转换出错
# 第55条数据转换出错
# 第56条数据转换出错
# 第57条数据转换出错
# 第58条数据转换出错
# 第59条数据转换出错
# 第60条数据转换出错
# 第61条数据转换出错
# 第62条数据转换出错
# 第63条数据转换出错
# 第64条数据转换出错
# 第65条数据转换出错
# 第66条数据转换出错
# 第67条数据转换出错
# 第68条数据转换出错
# 第69条数据转换出错
# 第70条数据转换出错
# 第71条数据转换出错
# 第72条数据转换出错
# 第73条数据转换出错
# 第74条数据转换出错
# 第75条数据转换出错
# 第76条数据转换出错
# 第77条数据转换出错
# 第78条数据转换出错
#   0%|▎                                                                             | 79/17058 [00:00<00:42, 403.61it/s]
# 第79条数据转换出错
# 第80条数据转换出错
# 第81条数据转换出错
# 第82条数据转换出错
# 第83条数据转换出错
# 第84条数据转换出错
# 第85条数据转换出错
# 第86条数据转换出错
# 第87条数据转换出错
# 第88条数据转换出错
# 第89条数据转换出错
# 第90条数据转换出错
# 第91条数据转换出错
# 第92条数据转换出错
# 第93条数据转换出错
# 第94条数据转换出错
# 第95条数据转换出错
# 第96条数据转换出错
# 第97条数据转换出错
# 第98条数据转换出错
# 第99条数据转换出错
# 第100条数据转换出错
# 第101条数据转换出错
# 第102条数据转换出错
# 第103条数据转换出错
# 第104条数据转换出错
# 第105条数据转换出错
# 第106条数据转换出错
# 第107条数据转换出错
# 第108条数据转换出错
# 第109条数据转换出错
# 第110条数据转换出错
# 第111条数据转换出错
# 第112条数据转换出错
# 第113条数据转换出错
# 第114条数据转换出错
# 第115条数据转换出错
#   1%|▌                                                                            | 116/17058 [00:00<00:43, 391.99it/s]
# 第116条数据转换出错
# 第117条数据转换出错
# 第118条数据转换出错
# 第119条数据转换出错
# 第120条数据转换出错
# 第121条数据转换出错
# 第122条数据转换出错
# 第123条数据转换出错
# 第124条数据转换出错
# 第125条数据转换出错
# 第126条数据转换出错
# 第127条数据转换出错
# 第128条数据转换出错
# 第129条数据转换出错
# 第130条数据转换出错
# 第131条数据转换出错
# 第132条数据转换出错
# 第133条数据转换出错
# 第134条数据转换出错
# 第135条数据转换出错
# 第136条数据转换出错
# 第137条数据转换出错
# 第138条数据转换出错
# 第139条数据转换出错
# 第140条数据转换出错
#   1%|▋                                                                            | 141/17058 [00:00<00:57, 296.08it/s]
# 第141条数据转换出错
# 第142条数据转换出错
# 第143条数据转换出错
# 第144条数据转换出错
# 第145条数据转换出错
# 第146条数据转换出错
# 第147条数据转换出错
# 第148条数据转换出错
# 第149条数据转换出错
# 第150条数据转换出错
# 第151条数据转换出错
# 第152条数据转换出错
# 第153条数据转换出错
# 第154条数据转换出错
# 第155条数据转换出错
# 第156条数据转换出错
# 第157条数据转换出错
# 第158条数据转换出错
# 第159条数据转换出错
# 第160条数据转换出错
# 第161条数据转换出错
# 第162条数据转换出错
# 第163条数据转换出错
# 第164条数据转换出错
# 第165条数据转换出错
# 第166条数据转换出错
# 第167条数据转换出错
# 第168条数据转换出错
# 第169条数据转换出错
# 第170条数据转换出错
# 第171条数据转换出错
# 第172条数据转换出错
# 第173条数据转换出错
# 第174条数据转换出错
# 第175条数据转换出错
# 第176条数据转换出错
# 第177条数据转换出错
#   1%|▊                                                                            | 178/17058 [00:00<00:53, 312.78it/s]
# 第178条数据转换出错
# 第179条数据转换出错
# 第180条数据转换出错
# 第181条数据转换出错
# 第182条数据转换出错
# 第183条数据转换出错
# 第184条数据转换出错
# 第185条数据转换出错
# 第186条数据转换出错
# 第187条数据转换出错
# 第188条数据转换出错
# 第189条数据转换出错
# 第190条数据转换出错
# 第191条数据转换出错
# 第192条数据转换出错
# 第193条数据转换出错
# 第194条数据转换出错
# 第195条数据转换出错
# 第196条数据转换出错
# 第197条数据转换出错
# 第198条数据转换出错
# 第199条数据转换出错
# 第200条数据转换出错
# 第201条数据转换出错
# 第202条数据转换出错
# 第203条数据转换出错
# 第204条数据转换出错
# 第205条数据转换出错
# 第206条数据转换出错
# 第207条数据转换出错
# 第208条数据转换出错
# 第209条数据转换出错
#   1%|▉                                                                            | 210/17058 [00:00<00:53, 314.23it/s]
# 第210条数据转换出错
# 第211条数据转换出错
# 第212条数据转换出错
# 第213条数据转换出错
# 第214条数据转换出错
# 第215条数据转换出错
# 第216条数据转换出错
# 第217条数据转换出错
# 第218条数据转换出错
# 第219条数据转换出错
# 第220条数据转换出错
# 第221条数据转换出错
# 第222条数据转换出错
# 第223条数据转换出错
# 第224条数据转换出错
# 第225条数据转换出错
# 第226条数据转换出错
# 第227条数据转换出错
# 第228条数据转换出错
# 第229条数据转换出错
# 第230条数据转换出错
# 第231条数据转换出错
# 第232条数据转换出错
# 第233条数据转换出错
# 第234条数据转换出错
# 第235条数据转换出错
# 第236条数据转换出错
# 第237条数据转换出错
# 第238条数据转换出错
#   1%|█                                                                            | 239/17058 [00:00<01:02, 268.55it/s]
# 第239条数据转换出错
# 第240条数据转换出错
# 第241条数据转换出错
# 第242条数据转换出错
# 第243条数据转换出错
# 第244条数据转换出错
# 第245条数据转换出错
# 第246条数据转换出错
# 第247条数据转换出错
# 第248条数据转换出错
# 第249条数据转换出错
# 第250条数据转换出错
# 第251条数据转换出错
# 第252条数据转换出错
# 第253条数据转换出错
# 第254条数据转换出错
# 第255条数据转换出错
# 第256条数据转换出错
# 第257条数据转换出错
# 第258条数据转换出错
# 第259条数据转换出错
# 第260条数据转换出错
# 第261条数据转换出错
# 第262条数据转换出错
# 第263条数据转换出错
# 第264条数据转换出错
# 第265条数据转换出错
# 第266条数据转换出错
# 第267条数据转换出错
# 第268条数据转换出错
# 第269条数据转换出错
# 第270条数据转换出错
# 第271条数据转换出错
# 第272条数据转换出错
# 第273条数据转换出错
# 第274条数据转换出错
# 第275条数据转换出错
#   2%|█▏                                                                           | 276/17058 [00:00<00:57, 291.43it/s]
# 第276条数据转换出错
# 第277条数据转换出错
# 第278条数据转换出错
# 第279条数据转换出错
# 第280条数据转换出错
# 第281条数据转换出错
# 第282条数据转换出错
# 第283条数据转换出错
# 第284条数据转换出错
# 第285条数据转换出错
# 第286条数据转换出错
# 第287条数据转换出错
# 第288条数据转换出错
# 第289条数据转换出错
# 第290条数据转换出错
# 第291条数据转换出错
# 第292条数据转换出错
# 第293条数据转换出错
# 第294条数据转换出错
# 第295条数据转换出错
# 第296条数据转换出错
# 第297条数据转换出错
# 第298条数据转换出错
# 第299条数据转换出错
# 第300条数据转换出错
# 第301条数据转换出错
# 第302条数据转换出错
# 第303条数据转换出错
# 第304条数据转换出错
#   2%|█▍                                                                           | 305/17058 [00:01<01:01, 273.17it/s]
# 第305条数据转换出错
# 第306条数据转换出错
# 第307条数据转换出错
# 第308条数据转换出错
# 第309条数据转换出错
# 第310条数据转换出错
# 第311条数据转换出错
# 第312条数据转换出错
# 第313条数据转换出错
# 第314条数据转换出错
# 第315条数据转换出错
# 第316条数据转换出错
# 第317条数据转换出错
# 第318条数据转换出错
# 第319条数据转换出错
# 第320条数据转换出错
# 第321条数据转换出错
# 第322条数据转换出错
# 第323条数据转换出错
# 第324条数据转换出错
# 第325条数据转换出错
# 第326条数据转换出错
# 第327条数据转换出错
# 第328条数据转换出错
# 第329条数据转换出错
# 第330条数据转换出错
# 第331条数据转换出错
# 第332条数据转换出错
# 第333条数据转换出错
#   2%|█▌                                                                           | 334/17058 [00:01<01:00, 276.64it/s]
# 第334条数据转换出错
# 第335条数据转换出错
# 第336条数据转换出错
# 第337条数据转换出错
# 第338条数据转换出错
# 第339条数据转换出错
# 第340条数据转换出错
# 第341条数据转换出错
# 第342条数据转换出错
# 第343条数据转换出错
# 第344条数据转换出错
# 第345条数据转换出错
# 第346条数据转换出错
# 第347条数据转换出错
# 第348条数据转换出错
# 第349条数据转换出错
# 第350条数据转换出错
# 第351条数据转换出错
# 第352条数据转换出错
# 第353条数据转换出错
# 第354条数据转换出错
# 第355条数据转换出错
# 第356条数据转换出错
# 第357条数据转换出错
# 第358条数据转换出错
# 第359条数据转换出错
# 第360条数据转换出错
# 第361条数据转换出错
# 第362条数据转换出错
# 第363条数据转换出错
# 第364条数据转换出错
# 第365条数据转换出错
# 第366条数据转换出错
# 第367条数据转换出错
# 第368条数据转换出错
# 第369条数据转换出错
# 第370条数据转换出错
# 第371条数据转换出错
#   2%|█▋                                                                           | 372/17058 [00:01<00:56, 297.87it/s]
# 第372条数据转换出错
# 第373条数据转换出错
# 第374条数据转换出错
# 第375条数据转换出错
# 第376条数据转换出错
# 第377条数据转换出错
# 第378条数据转换出错
# 第379条数据转换出错
# 第380条数据转换出错
# 第381条数据转换出错
# 第382条数据转换出错
# 第383条数据转换出错
# 第384条数据转换出错
# 第385条数据转换出错
# 第386条数据转换出错
# 第387条数据转换出错
# 第388条数据转换出错
# 第389条数据转换出错
# 第390条数据转换出错
# 第391条数据转换出错
# 第392条数据转换出错
# 第393条数据转换出错
# 第394条数据转换出错
# 第395条数据转换出错
# 第396条数据转换出错
# 第397条数据转换出错
# 第398条数据转换出错
# 第399条数据转换出错
# 第400条数据转换出错
# 第401条数据转换出错
# 第402条数据转换出错
# 第403条数据转换出错
#   2%|█▊                                                                           | 404/17058 [00:01<00:55, 301.84it/s]
# 第404条数据转换出错
# 第405条数据转换出错
# 第406条数据转换出错
# 第407条数据转换出错
# 第408条数据转换出错
# 第409条数据转换出错
# 第410条数据转换出错
# 第411条数据转换出错
# 第412条数据转换出错
# 第413条数据转换出错
# 第414条数据转换出错
# 第415条数据转换出错
# 第416条数据转换出错
# 第417条数据转换出错
# 第418条数据转换出错
# 第419条数据转换出错
# 第420条数据转换出错
# 第421条数据转换出错
# 第422条数据转换出错
# 第423条数据转换出错
# 第424条数据转换出错
# 第425条数据转换出错
# 第426条数据转换出错
# 第427条数据转换出错
# 第428条数据转换出错
# 第429条数据转换出错
# 第430条数据转换出错
# 第431条数据转换出错
# 第432条数据转换出错
# 第433条数据转换出错
# 第434条数据转换出错
#   3%|█▉                                                                           | 435/17058 [00:01<00:56, 294.95it/s]
# 第435条数据转换出错
# 第436条数据转换出错
# 第437条数据转换出错
# 第438条数据转换出错
# 第439条数据转换出错
# 第440条数据转换出错
# 第441条数据转换出错
# 第442条数据转换出错
# 第443条数据转换出错
# 第444条数据转换出错
# 第445条数据转换出错
# 第446条数据转换出错
# 第447条数据转换出错
# 第448条数据转换出错
# 第449条数据转换出错
# 第450条数据转换出错
# 第451条数据转换出错
# 第452条数据转换出错
# 第453条数据转换出错
# 第454条数据转换出错
# 第455条数据转换出错
# 第456条数据转换出错
# 第457条数据转换出错
# 第458条数据转换出错
# 第459条数据转换出错
# 第460条数据转换出错
# 第461条数据转换出错
# 第462条数据转换出错
# 第463条数据转换出错
# 第464条数据转换出错
# 第465条数据转换出错
# 第466条数据转换出错
# 第467条数据转换出错
# 第468条数据转换出错
#   3%|██                                                                           | 469/17058 [00:01<00:54, 305.72it/s]
# 第469条数据转换出错
# 第470条数据转换出错
# 第471条数据转换出错
# 第472条数据转换出错
# 第473条数据转换出错
# 第474条数据转换出错
# 第475条数据转换出错
# 第476条数据转换出错
# 第477条数据转换出错
# 第478条数据转换出错
# 第479条数据转换出错
# 第480条数据转换出错
# 第481条数据转换出错
# 第482条数据转换出错
# 第483条数据转换出错
# 第484条数据转换出错
# 第485条数据转换出错
# 第486条数据转换出错
# 第487条数据转换出错
# 第488条数据转换出错
# 第489条数据转换出错
# 第490条数据转换出错
# 第491条数据转换出错
# 第492条数据转换出错
# 第493条数据转换出错
# 第494条数据转换出错
# 第495条数据转换出错
# 第496条数据转换出错
# 第497条数据转换出错
# 第498条数据转换出错
# 第499条数据转换出错
# 第500条数据转换出错
# 第501条数据转换出错
# 第502条数据转换出错
#   3%|██▎                                                                          | 503/17058 [00:01<00:52, 313.75it/s]
# 第503条数据转换出错
# 第504条数据转换出错
# 第505条数据转换出错
# 第506条数据转换出错
# 第507条数据转换出错
# 第508条数据转换出错
# 第509条数据转换出错
# 第510条数据转换出错
# 第511条数据转换出错
# 第512条数据转换出错
# 第513条数据转换出错
# 第514条数据转换出错
# 第515条数据转换出错
# 第516条数据转换出错
# 第517条数据转换出错
# 第518条数据转换出错
# 第519条数据转换出错
# 第520条数据转换出错
# 第521条数据转换出错
# 第522条数据转换出错
# 第523条数据转换出错
# 第524条数据转换出错
# 第525条数据转换出错
# 第526条数据转换出错
# 第527条数据转换出错
# 第528条数据转换出错
# 第529条数据转换出错
# 第530条数据转换出错
# 第531条数据转换出错
# 第532条数据转换出错
# 第533条数据转换出错
# 第534条数据转换出错
#   3%|██▍                                                                          | 535/17058 [00:01<01:00, 275.21it/s]
# 第535条数据转换出错
# 第536条数据转换出错
# 第537条数据转换出错
# 第538条数据转换出错
# 第539条数据转换出错
# 第540条数据转换出错
# 第541条数据转换出错
# 第542条数据转换出错
# 第543条数据转换出错
# 第544条数据转换出错
# 第545条数据转换出错
# 第546条数据转换出错
# 第547条数据转换出错
# 第548条数据转换出错
# 第549条数据转换出错
# 第550条数据转换出错
# 第551条数据转换出错
# 第552条数据转换出错
# 第553条数据转换出错
# 第554条数据转换出错
# 第555条数据转换出错
# 第556条数据转换出错
# 第557条数据转换出错
# 第558条数据转换出错
# 第559条数据转换出错
# 第560条数据转换出错
# 第561条数据转换出错
# 第562条数据转换出错
# 第563条数据转换出错
# 第564条数据转换出错
#   3%|██▌                                                                          | 565/17058 [00:01<00:58, 281.63it/s]
# 第565条数据转换出错
# 第566条数据转换出错
# 第567条数据转换出错
# 第568条数据转换出错
# 第569条数据转换出错
# 第570条数据转换出错
# 第571条数据转换出错
# 第572条数据转换出错
# 第573条数据转换出错
# 第574条数据转换出错
# 第575条数据转换出错
# 第576条数据转换出错
# 第577条数据转换出错
# 第578条数据转换出错
# 第579条数据转换出错
# 第580条数据转换出错
# 第581条数据转换出错
# 第582条数据转换出错
# 第583条数据转换出错
# 第584条数据转换出错
# 第585条数据转换出错
# 第586条数据转换出错
# 第587条数据转换出错
# 第588条数据转换出错
# 第589条数据转换出错
# 第590条数据转换出错
# 第591条数据转换出错
# 第592条数据转换出错
# 第593条数据转换出错
#   3%|██▋                                                                          | 594/17058 [00:01<00:58, 282.65it/s]
# 第594条数据转换出错
# 第595条数据转换出错
# 第596条数据转换出错
# 第597条数据转换出错
# 第598条数据转换出错
# 第599条数据转换出错
# 第600条数据转换出错
# 第601条数据转换出错
# 第602条数据转换出错
# 第603条数据转换出错
# 第604条数据转换出错
# 第605条数据转换出错
# 第606条数据转换出错
# 第607条数据转换出错
# 第608条数据转换出错
# 第609条数据转换出错
# 第610条数据转换出错
# 第611条数据转换出错
# 第612条数据转换出错
# 第613条数据转换出错
# 第614条数据转换出错
# 第615条数据转换出错
# 第616条数据转换出错
# 第617条数据转换出错
# 第618条数据转换出错
# 第619条数据转换出错
# 第620条数据转换出错
# 第621条数据转换出错
# 第622条数据转换出错
# 第623条数据转换出错
# 第624条数据转换出错
# 第625条数据转换出错
# 第626条数据转换出错
# 第627条数据转换出错
# 第628条数据转换出错
# 第629条数据转换出错
#   4%|██▊                                                                          | 630/17058 [00:02<00:54, 300.82it/s]
# 第630条数据转换出错
# 第631条数据转换出错
# 第632条数据转换出错
# 第633条数据转换出错
# 第634条数据转换出错
# 第635条数据转换出错
# 第636条数据转换出错
# 第637条数据转换出错
# 第638条数据转换出错
# 第639条数据转换出错
# 第640条数据转换出错
# 第641条数据转换出错
# 第642条数据转换出错
# 第643条数据转换出错
# 第644条数据转换出错
# 第645条数据转换出错
# 第646条数据转换出错
# 第647条数据转换出错
# 第648条数据转换出错
# 第649条数据转换出错
# 第650条数据转换出错
# 第651条数据转换出错
# 第652条数据转换出错
# 第653条数据转换出错
# 第654条数据转换出错
# 第655条数据转换出错
# 第656条数据转换出错
# 第657条数据转换出错
# 第658条数据转换出错
# 第659条数据转换出错
# 第660条数据转换出错
#   4%|██▉                                                                          | 661/17058 [00:02<00:54, 302.84it/s]
# 第661条数据转换出错
# 第662条数据转换出错
# 第663条数据转换出错
# 第664条数据转换出错
# 第665条数据转换出错
# 第666条数据转换出错
# 第667条数据转换出错
# 第668条数据转换出错
# 第669条数据转换出错
# 第670条数据转换出错
# 第671条数据转换出错
# 第672条数据转换出错
# 第673条数据转换出错
# 第674条数据转换出错
# 第675条数据转换出错
# 第676条数据转换出错
# 第677条数据转换出错
# 第678条数据转换出错
# 第679条数据转换出错
# 第680条数据转换出错
# 第681条数据转换出错
# 第682条数据转换出错
# 第683条数据转换出错
# 第684条数据转换出错
# 第685条数据转换出错
# 第686条数据转换出错
# 第687条数据转换出错
# 第688条数据转换出错
# 第689条数据转换出错
# 第690条数据转换出错
# 第691条数据转换出错
# 第692条数据转换出错
# 第693条数据转换出错
# 第694条数据转换出错
# 第695条数据转换出错
# 第696条数据转换出错
# 第697条数据转换出错
#   4%|███▏                                                                         | 698/17058 [00:02<00:51, 319.70it/s]
# 第698条数据转换出错
# 第699条数据转换出错
# 第700条数据转换出错
# 第701条数据转换出错
# 第702条数据转换出错
# 第703条数据转换出错
# 第704条数据转换出错
# 第705条数据转换出错
# 第706条数据转换出错
# 第707条数据转换出错
# 第708条数据转换出错
# 第709条数据转换出错
# 第710条数据转换出错
# 第711条数据转换出错
# 第712条数据转换出错
# 第713条数据转换出错
# 第714条数据转换出错
# 第715条数据转换出错
# 第716条数据转换出错
# 第717条数据转换出错
# 第718条数据转换出错
# 第719条数据转换出错
# 第720条数据转换出错
# 第721条数据转换出错
# 第722条数据转换出错
# 第723条数据转换出错
# 第724条数据转换出错
# 第725条数据转换出错
# 第726条数据转换出错
# 第727条数据转换出错
# 第728条数据转换出错
# 第729条数据转换出错
# 第730条数据转换出错
#   4%|███▎                                                                         | 731/17058 [00:02<00:59, 275.39it/s]
# 第731条数据转换出错
# 第732条数据转换出错
# 第733条数据转换出错
# 第734条数据转换出错
# 第735条数据转换出错
# 第736条数据转换出错
# 第737条数据转换出错
# 第738条数据转换出错
# 第739条数据转换出错
# 第740条数据转换出错
# 第741条数据转换出错
# 第742条数据转换出错
# 第743条数据转换出错
# 第744条数据转换出错
# 第745条数据转换出错
# 第746条数据转换出错
# 第747条数据转换出错
# 第748条数据转换出错
# 第749条数据转换出错
# 第750条数据转换出错
# 第751条数据转换出错
# 第752条数据转换出错
# 第753条数据转换出错
# 第754条数据转换出错
# 第755条数据转换出错
# 第756条数据转换出错
# 第757条数据转换出错
# 第758条数据转换出错
# 第759条数据转换出错
# 第760条数据转换出错
#   4%|███▍                                                                         | 761/17058 [00:02<00:59, 273.31it/s]
# 第761条数据转换出错
# 第762条数据转换出错
# 第763条数据转换出错
# 第764条数据转换出错
# 第765条数据转换出错
# 第766条数据转换出错
# 第767条数据转换出错
# 第768条数据转换出错
# 第769条数据转换出错
# 第770条数据转换出错
# 第771条数据转换出错
# 第772条数据转换出错
# 第773条数据转换出错
# 第774条数据转换出错
# 第775条数据转换出错
# 第776条数据转换出错
# 第777条数据转换出错
# 第778条数据转换出错
# 第779条数据转换出错
# 第780条数据转换出错
# 第781条数据转换出错
# 第782条数据转换出错
# 第783条数据转换出错
# 第784条数据转换出错
# 第785条数据转换出错
# 第786条数据转换出错
# 第787条数据转换出错
# 第788条数据转换出错
# 第789条数据转换出错
# 第790条数据转换出错
# 第791条数据转换出错
# 第792条数据转换出错
# 第793条数据转换出错
# 第794条数据转换出错
# 第795条数据转换出错
# 第796条数据转换出错
# 第797条数据转换出错
# 第798条数据转换出错
# 第799条数据转换出错
# 第800条数据转换出错
# 第801条数据转换出错
# 第802条数据转换出错
# 第803条数据转换出错
# 第804条数据转换出错
# 第805条数据转换出错
# 第806条数据转换出错
# 第807条数据转换出错
# 第808条数据转换出错
# 第809条数据转换出错
# 第810条数据转换出错
# 第811条数据转换出错
# 第812条数据转换出错
# 第813条数据转换出错
# 第814条数据转换出错
#   5%|███▋                                                                         | 815/17058 [00:02<00:51, 314.84it/s]
# 第815条数据转换出错
# 第816条数据转换出错
# 第817条数据转换出错
# 第818条数据转换出错
# 第819条数据转换出错
# 第820条数据转换出错
# 第821条数据转换出错
# 第822条数据转换出错
# 第823条数据转换出错
# 第824条数据转换出错
# 第825条数据转换出错
# 第826条数据转换出错
# 第827条数据转换出错
# 第828条数据转换出错
# 第829条数据转换出错
# 第830条数据转换出错
# 第831条数据转换出错
# 第832条数据转换出错
# 第833条数据转换出错
# 第834条数据转换出错
# 第835条数据转换出错
# 第836条数据转换出错
# 第837条数据转换出错
# 第838条数据转换出错
# 第839条数据转换出错
# 第840条数据转换出错
# 第841条数据转换出错
# 第842条数据转换出错
# 第843条数据转换出错
# 第844条数据转换出错
# 第845条数据转换出错
# 第846条数据转换出错
# 第847条数据转换出错
# 第848条数据转换出错
# 第849条数据转换出错
# 第850条数据转换出错
# 第851条数据转换出错
# 第852条数据转换出错
# 第853条数据转换出错
# 第854条数据转换出错
#   5%|███▊                                                                         | 855/17058 [00:02<00:48, 334.03it/s]
# 第855条数据转换出错
# 第856条数据转换出错
# 第857条数据转换出错
# 第858条数据转换出错
# 第859条数据转换出错
# 第860条数据转换出错
# 第861条数据转换出错
# 第862条数据转换出错
# 第863条数据转换出错
# 第864条数据转换出错
# 第865条数据转换出错
# 第866条数据转换出错
# 第867条数据转换出错
# 第868条数据转换出错
# 第869条数据转换出错
# 第870条数据转换出错
# 第871条数据转换出错
# 第872条数据转换出错
# 第873条数据转换出错
# 第874条数据转换出错
# 第875条数据转换出错
# 第876条数据转换出错
# 第877条数据转换出错
# 第878条数据转换出错
# 第879条数据转换出错
# 第880条数据转换出错
# 第881条数据转换出错
# 第882条数据转换出错
# 第883条数据转换出错
# 第884条数据转换出错
# 第885条数据转换出错
# 第886条数据转换出错
# 第887条数据转换出错
# 第888条数据转换出错
# 第889条数据转换出错
# 第890条数据转换出错
# 第891条数据转换出错
# 第892条数据转换出错
#   5%|████                                                                         | 893/17058 [00:02<00:46, 345.91it/s]
# 第893条数据转换出错
# 第894条数据转换出错
# 第895条数据转换出错
# 第896条数据转换出错
# 第897条数据转换出错
# 第898条数据转换出错
# 第899条数据转换出错
# 第900条数据转换出错
# 第901条数据转换出错
# 第902条数据转换出错
# 第903条数据转换出错
# 第904条数据转换出错
# 第905条数据转换出错
# 第906条数据转换出错
# 第907条数据转换出错
# 第908条数据转换出错
# 第909条数据转换出错
# 第910条数据转换出错
# 第911条数据转换出错
# 第912条数据转换出错
# 第913条数据转换出错
# 第914条数据转换出错
# 第915条数据转换出错
# 第916条数据转换出错
# 第917条数据转换出错
# 第918条数据转换出错
# 第919条数据转换出错
# 第920条数据转换出错
# 第921条数据转换出错
# 第922条数据转换出错
# 第923条数据转换出错
# 第924条数据转换出错
# 第925条数据转换出错
# 第926条数据转换出错
# 第927条数据转换出错
# 第928条数据转换出错
# 第929条数据转换出错
#   5%|████▏                                                                        | 930/17058 [00:03<00:50, 321.00it/s]
# 第930条数据转换出错
# 第931条数据转换出错
# 第932条数据转换出错
# 第933条数据转换出错
# 第934条数据转换出错
# 第935条数据转换出错
# 第936条数据转换出错
# 第937条数据转换出错
# 第938条数据转换出错
# 第939条数据转换出错
# 第940条数据转换出错
# 第941条数据转换出错
# 第942条数据转换出错
# 第943条数据转换出错
# 第944条数据转换出错
# 第945条数据转换出错
# 第946条数据转换出错
# 第947条数据转换出错
# 第948条数据转换出错
# 第949条数据转换出错
# 第950条数据转换出错
# 第951条数据转换出错
# 第952条数据转换出错
# 第953条数据转换出错
# 第954条数据转换出错
# 第955条数据转换出错
# 第956条数据转换出错
# 第957条数据转换出错
# 第958条数据转换出错
# 第959条数据转换出错
# 第960条数据转换出错
# 第961条数据转换出错
# 第962条数据转换出错
# 第963条数据转换出错
#   6%|████▎                                                                        | 964/17058 [00:03<00:59, 270.04it/s]
# 第964条数据转换出错
# 第965条数据转换出错
# 第966条数据转换出错
# 第967条数据转换出错
# 第968条数据转换出错
# 第969条数据转换出错
# 第970条数据转换出错
# 第971条数据转换出错
# 第972条数据转换出错
# 第973条数据转换出错
# 第974条数据转换出错
# 第975条数据转换出错
# 第976条数据转换出错
# 第977条数据转换出错
# 第978条数据转换出错
# 第979条数据转换出错
# 第980条数据转换出错
# 第981条数据转换出错
# 第982条数据转换出错
# 第983条数据转换出错
# 第984条数据转换出错
# 第985条数据转换出错
# 第986条数据转换出错
# 第987条数据转换出错
# 第988条数据转换出错
# 第989条数据转换出错
# 第990条数据转换出错
# 第991条数据转换出错
# 第992条数据转换出错
# 第993条数据转换出错
#   6%|████▍                                                                        | 994/17058 [00:03<00:59, 271.79it/s]
# 第994条数据转换出错
# 第995条数据转换出错
# 第996条数据转换出错
# 第997条数据转换出错
# 第998条数据转换出错
# 第999条数据转换出错
# 第1000条数据转换出错
# 第1001条数据转换出错
# 第1002条数据转换出错
# 第1003条数据转换出错
# 第1004条数据转换出错
# 第1005条数据转换出错
# 第1006条数据转换出错
# 第1007条数据转换出错
# 第1008条数据转换出错
# 第1009条数据转换出错
# 第1010条数据转换出错
# 第1011条数据转换出错
# 第1012条数据转换出错
# 第1013条数据转换出错
# 第1014条数据转换出错
# 第1015条数据转换出错
# 第1016条数据转换出错
# 第1017条数据转换出错
# 第1018条数据转换出错
# 第1019条数据转换出错
# 第1020条数据转换出错
# 第1021条数据转换出错
# 第1022条数据转换出错
# 第1023条数据转换出错
# 第1024条数据转换出错
# 第1025条数据转换出错
# 第1026条数据转换出错
# 第1027条数据转换出错
# 第1028条数据转换出错
#   6%|████▌                                                                       | 1029/17058 [00:03<00:55, 290.78it/s]
# 第1029条数据转换出错
# 第1030条数据转换出错
# 第1031条数据转换出错
# 第1032条数据转换出错
# 第1033条数据转换出错
# 第1034条数据转换出错
# 第1035条数据转换出错
# 第1036条数据转换出错
# 第1037条数据转换出错
# 第1038条数据转换出错
# 第1039条数据转换出错
# 第1040条数据转换出错
# 第1041条数据转换出错
# 第1042条数据转换出错
# 第1043条数据转换出错
# 第1044条数据转换出错
# 第1045条数据转换出错
# 第1046条数据转换出错
# 第1047条数据转换出错
# 第1048条数据转换出错
# 第1049条数据转换出错
# 第1050条数据转换出错
# 第1051条数据转换出错
# 第1052条数据转换出错
# 第1053条数据转换出错
# 第1054条数据转换出错
# 第1055条数据转换出错
# 第1056条数据转换出错
# 第1057条数据转换出错
# 第1058条数据转换出错
# 第1059条数据转换出错
# 第1060条数据转换出错
# 第1061条数据转换出错
# 第1062条数据转换出错
# 第1063条数据转换出错
# 第1064条数据转换出错
# 第1065条数据转换出错
# 第1066条数据转换出错
#   6%|████▊                                                                       | 1067/17058 [00:03<00:51, 312.26it/s]
# 第1067条数据转换出错
# 第1068条数据转换出错
# 第1069条数据转换出错
# 第1070条数据转换出错
# 第1071条数据转换出错
# 第1072条数据转换出错
# 第1073条数据转换出错
# 第1074条数据转换出错
# 第1075条数据转换出错
# 第1076条数据转换出错
# 第1077条数据转换出错
# 第1078条数据转换出错
# 第1079条数据转换出错
# 第1080条数据转换出错
# 第1081条数据转换出错
# 第1082条数据转换出错
# 第1083条数据转换出错
# 第1084条数据转换出错
# 第1085条数据转换出错
# 第1086条数据转换出错
# 第1087条数据转换出错
# 第1088条数据转换出错
# 第1089条数据转换出错
# 第1090条数据转换出错
# 第1091条数据转换出错
# 第1092条数据转换出错
# 第1093条数据转换出错
# 第1094条数据转换出错
# 第1095条数据转换出错
# 第1096条数据转换出错
# 第1097条数据转换出错
# 第1098条数据转换出错
# 第1099条数据转换出错
#   6%|████▉                                                                       | 1100/17058 [00:03<00:55, 287.77it/s]
# 第1100条数据转换出错
# 第1101条数据转换出错
# 第1102条数据转换出错
# 第1103条数据转换出错
# 第1104条数据转换出错
# 第1105条数据转换出错
# 第1106条数据转换出错
# 第1107条数据转换出错
# 第1108条数据转换出错
# 第1109条数据转换出错
# 第1110条数据转换出错
# 第1111条数据转换出错
# 第1112条数据转换出错
# 第1113条数据转换出错
# 第1114条数据转换出错
# 第1115条数据转换出错
# 第1116条数据转换出错
# 第1117条数据转换出错
# 第1118条数据转换出错
# 第1119条数据转换出错
# 第1120条数据转换出错
# 第1121条数据转换出错
# 第1122条数据转换出错
# 第1123条数据转换出错
# 第1124条数据转换出错
# 第1125条数据转换出错
# 第1126条数据转换出错
# 第1127条数据转换出错
# 第1128条数据转换出错
# 第1129条数据转换出错
# 第1130条数据转换出错
#   7%|█████                                                                       | 1131/17058 [00:03<01:00, 262.30it/s]
# 第1131条数据转换出错
# 第1132条数据转换出错
# 第1133条数据转换出错
# 第1134条数据转换出错
# 第1135条数据转换出错
# 第1136条数据转换出错
# 第1137条数据转换出错
# 第1138条数据转换出错
# 第1139条数据转换出错
# 第1140条数据转换出错
# 第1141条数据转换出错
# 第1142条数据转换出错
# 第1143条数据转换出错
# 第1144条数据转换出错
# 第1145条数据转换出错
# 第1146条数据转换出错
# 第1147条数据转换出错
# 第1148条数据转换出错
# 第1149条数据转换出错
# 第1150条数据转换出错
# 第1151条数据转换出错
# 第1152条数据转换出错
# 第1153条数据转换出错
# 第1154条数据转换出错
# 第1155条数据转换出错
# 第1156条数据转换出错
# 第1157条数据转换出错
# 第1158条数据转换出错
#   7%|█████▏                                                                      | 1159/17058 [00:03<01:14, 212.33it/s]
# 第1159条数据转换出错
# 第1160条数据转换出错
# 第1161条数据转换出错
# 第1162条数据转换出错
# 第1163条数据转换出错
# 第1164条数据转换出错
# 第1165条数据转换出错
# 第1166条数据转换出错
# 第1167条数据转换出错
# 第1168条数据转换出错
# 第1169条数据转换出错
# 第1170条数据转换出错
# 第1171条数据转换出错
# 第1172条数据转换出错
# 第1173条数据转换出错
# 第1174条数据转换出错
# 第1175条数据转换出错
# 第1176条数据转换出错
# 第1177条数据转换出错
# 第1178条数据转换出错
# 第1179条数据转换出错
# 第1180条数据转换出错
# 第1181条数据转换出错
# 第1182条数据转换出错
# 第1183条数据转换出错
# 第1184条数据转换出错
# 第1185条数据转换出错
# 第1186条数据转换出错
# 第1187条数据转换出错
# 第1188条数据转换出错
# 第1189条数据转换出错
# 第1190条数据转换出错
#   7%|█████▎                                                                      | 1191/17058 [00:04<01:07, 235.27it/s]
# 第1191条数据转换出错
# 第1192条数据转换出错
# 第1193条数据转换出错
# 第1194条数据转换出错
# 第1195条数据转换出错
# 第1196条数据转换出错
# 第1197条数据转换出错
# 第1198条数据转换出错
# 第1199条数据转换出错
# 第1200条数据转换出错
# 第1201条数据转换出错
# 第1202条数据转换出错
# 第1203条数据转换出错
# 第1204条数据转换出错
# 第1205条数据转换出错
# 第1206条数据转换出错
# 第1207条数据转换出错
# 第1208条数据转换出错
# 第1209条数据转换出错
# 第1210条数据转换出错
# 第1211条数据转换出错
# 第1212条数据转换出错
# 第1213条数据转换出错
# 第1214条数据转换出错
# 第1215条数据转换出错
# 第1216条数据转换出错
# 第1217条数据转换出错
# 第1218条数据转换出错
# 第1219条数据转换出错
# 第1220条数据转换出错
# 第1221条数据转换出错
# 第1222条数据转换出错
# 第1223条数据转换出错
# 第1224条数据转换出错
# 第1225条数据转换出错
# 第1226条数据转换出错
# 第1227条数据转换出错
# 第1228条数据转换出错
# 第1229条数据转换出错
#   7%|█████▍                                                                      | 1230/17058 [00:04<01:00, 262.89it/s]
# 第1230条数据转换出错
# 第1231条数据转换出错
# 第1232条数据转换出错
# 第1233条数据转换出错
# 第1234条数据转换出错
# 第1235条数据转换出错
# 第1236条数据转换出错
# 第1237条数据转换出错
# 第1238条数据转换出错
# 第1239条数据转换出错
# 第1240条数据转换出错
# 第1241条数据转换出错
# 第1242条数据转换出错
# 第1243条数据转换出错
# 第1244条数据转换出错
# 第1245条数据转换出错
# 第1246条数据转换出错
# 第1247条数据转换出错
# 第1248条数据转换出错
# 第1249条数据转换出错
# 第1250条数据转换出错
# 第1251条数据转换出错
# 第1252条数据转换出错
# 第1253条数据转换出错
# 第1254条数据转换出错
# 第1255条数据转换出错
# 第1256条数据转换出错
# 第1257条数据转换出错
# 第1258条数据转换出错
# 第1259条数据转换出错
#   7%|█████▌                                                                      | 1260/17058 [00:04<00:58, 270.27it/s]
# 第1260条数据转换出错
# 第1261条数据转换出错
# 第1262条数据转换出错
# 第1263条数据转换出错
# 第1264条数据转换出错
# 第1265条数据转换出错
# 第1266条数据转换出错
# 第1267条数据转换出错
# 第1268条数据转换出错
# 第1269条数据转换出错
# 第1270条数据转换出错
# 第1271条数据转换出错
# 第1272条数据转换出错
# 第1273条数据转换出错
# 第1274条数据转换出错
# 第1275条数据转换出错
# 第1276条数据转换出错
# 第1277条数据转换出错
# 第1278条数据转换出错
# 第1279条数据转换出错
# 第1280条数据转换出错
# 第1281条数据转换出错
# 第1282条数据转换出错
# 第1283条数据转换出错
# 第1284条数据转换出错
# 第1285条数据转换出错
# 第1286条数据转换出错
# 第1287条数据转换出错
# 第1288条数据转换出错
# 第1289条数据转换出错
# 第1290条数据转换出错
# 第1291条数据转换出错
#   8%|█████▊                                                                      | 1292/17058 [00:04<00:55, 282.94it/s]
# 第1292条数据转换出错
# 第1293条数据转换出错
# 第1294条数据转换出错
# 第1295条数据转换出错
# 第1296条数据转换出错
# 第1297条数据转换出错
# 第1298条数据转换出错
# 第1299条数据转换出错
# 第1300条数据转换出错
# 第1301条数据转换出错
# 第1302条数据转换出错
# 第1303条数据转换出错
# 第1304条数据转换出错
# 第1305条数据转换出错
# 第1306条数据转换出错
# 第1307条数据转换出错
# 第1308条数据转换出错
# 第1309条数据转换出错
# 第1310条数据转换出错
# 第1311条数据转换出错
# 第1312条数据转换出错
# 第1313条数据转换出错
# 第1314条数据转换出错
# 第1315条数据转换出错
# 第1316条数据转换出错
# 第1317条数据转换出错
# 第1318条数据转换出错
# 第1319条数据转换出错
# 第1320条数据转换出错
# 第1321条数据转换出错
# 第1322条数据转换出错
# 第1323条数据转换出错
# 第1324条数据转换出错
# 第1325条数据转换出错
# 第1326条数据转换出错
# 第1327条数据转换出错
# 第1328条数据转换出错
# 第1329条数据转换出错
# 第1330条数据转换出错
# 第1331条数据转换出错
# 第1332条数据转换出错
# 第1333条数据转换出错
# 第1334条数据转换出错
# 第1335条数据转换出错
# 第1336条数据转换出错
# 第1337条数据转换出错
# 第1338条数据转换出错
# 第1339条数据转换出错
#   8%|█████▉                                                                      | 1340/17058 [00:04<00:49, 320.26it/s]
# 第1340条数据转换出错
# 第1341条数据转换出错
# 第1342条数据转换出错
# 第1343条数据转换出错
# 第1344条数据转换出错
# 第1345条数据转换出错
# 第1346条数据转换出错
# 第1347条数据转换出错
# 第1348条数据转换出错
# 第1349条数据转换出错
# 第1350条数据转换出错
# 第1351条数据转换出错
# 第1352条数据转换出错
# 第1353条数据转换出错
# 第1354条数据转换出错
# 第1355条数据转换出错
# 第1356条数据转换出错
# 第1357条数据转换出错
# 第1358条数据转换出错
# 第1359条数据转换出错
# 第1360条数据转换出错
# 第1361条数据转换出错
# 第1362条数据转换出错
# 第1363条数据转换出错
# 第1364条数据转换出错
# 第1365条数据转换出错
# 第1366条数据转换出错
# 第1367条数据转换出错
# 第1368条数据转换出错
# 第1369条数据转换出错
# 第1370条数据转换出错
# 第1371条数据转换出错
# 第1372条数据转换出错
# 第1373条数据转换出错
# 第1374条数据转换出错
#   8%|██████▏                                                                     | 1375/17058 [00:04<00:51, 305.70it/s]
# 第1375条数据转换出错
# 第1376条数据转换出错
# 第1377条数据转换出错
# 第1378条数据转换出错
# 第1379条数据转换出错
# 第1380条数据转换出错
# 第1381条数据转换出错
# 第1382条数据转换出错
# 第1383条数据转换出错
# 第1384条数据转换出错
# 第1385条数据转换出错
# 第1386条数据转换出错
# 第1387条数据转换出错
# 第1388条数据转换出错
# 第1389条数据转换出错
# 第1390条数据转换出错
# 第1391条数据转换出错
# 第1392条数据转换出错
# 第1393条数据转换出错
# 第1394条数据转换出错
# 第1395条数据转换出错
# 第1396条数据转换出错
# 第1397条数据转换出错
# 第1398条数据转换出错
# 第1399条数据转换出错
# 第1400条数据转换出错
# 第1401条数据转换出错
# 第1402条数据转换出错
# 第1403条数据转换出错
# 第1404条数据转换出错
# 第1405条数据转换出错
# 第1406条数据转换出错
# 第1407条数据转换出错
#   8%|██████▎                                                                     | 1408/17058 [00:04<00:58, 269.30it/s]
# 第1408条数据转换出错
# 第1409条数据转换出错
# 第1410条数据转换出错
# 第1411条数据转换出错
# 第1412条数据转换出错
# 第1413条数据转换出错
# 第1414条数据转换出错
# 第1415条数据转换出错
# 第1416条数据转换出错
# 第1417条数据转换出错
# 第1418条数据转换出错
# 第1419条数据转换出错
# 第1420条数据转换出错
# 第1421条数据转换出错
# 第1422条数据转换出错
# 第1423条数据转换出错
# 第1424条数据转换出错
# 第1425条数据转换出错
# 第1426条数据转换出错
# 第1427条数据转换出错
# 第1428条数据转换出错
# 第1429条数据转换出错
# 第1430条数据转换出错
# 第1431条数据转换出错
# 第1432条数据转换出错
# 第1433条数据转换出错
# 第1434条数据转换出错
# 第1435条数据转换出错
# 第1436条数据转换出错
# 第1437条数据转换出错
# 第1438条数据转换出错
# 第1439条数据转换出错
# 第1440条数据转换出错
# 第1441条数据转换出错
# 第1442条数据转换出错
# 第1443条数据转换出错
# 第1444条数据转换出错
# 第1445条数据转换出错
# 第1446条数据转换出错
#   8%|██████▍                                                                     | 1447/17058 [00:04<00:52, 296.37it/s]
# 第1447条数据转换出错
# 第1448条数据转换出错
# 第1449条数据转换出错
# 第1450条数据转换出错
# 第1451条数据转换出错
# 第1452条数据转换出错
# 第1453条数据转换出错
# 第1454条数据转换出错
# 第1455条数据转换出错
# 第1456条数据转换出错
# 第1457条数据转换出错
# 第1458条数据转换出错
# 第1459条数据转换出错
# 第1460条数据转换出错
# 第1461条数据转换出错
# 第1462条数据转换出错
# 第1463条数据转换出错
# 第1464条数据转换出错
# 第1465条数据转换出错
# 第1466条数据转换出错
# 第1467条数据转换出错
# 第1468条数据转换出错
# 第1469条数据转换出错
# 第1470条数据转换出错
# 第1471条数据转换出错
# 第1472条数据转换出错
# 第1473条数据转换出错
# 第1474条数据转换出错
# 第1475条数据转换出错
# 第1476条数据转换出错
# 第1477条数据转换出错
# 第1478条数据转换出错
# 第1479条数据转换出错
#   9%|██████▌                                                                     | 1480/17058 [00:04<00:51, 302.59it/s]
# 第1480条数据转换出错
# 第1481条数据转换出错
# 第1482条数据转换出错
# 第1483条数据转换出错
# 第1484条数据转换出错
# 第1485条数据转换出错
# 第1486条数据转换出错
# 第1487条数据转换出错
# 第1488条数据转换出错
# 第1489条数据转换出错
# 第1490条数据转换出错
# 第1491条数据转换出错
# 第1492条数据转换出错
# 第1493条数据转换出错
# 第1494条数据转换出错
# 第1495条数据转换出错
# 第1496条数据转换出错
# 第1497条数据转换出错
# 第1498条数据转换出错
# 第1499条数据转换出错
# 第1500条数据转换出错
# 第1501条数据转换出错
# 第1502条数据转换出错
# 第1503条数据转换出错
# 第1504条数据转换出错
# 第1505条数据转换出错
# 第1506条数据转换出错
# 第1507条数据转换出错
# 第1508条数据转换出错
# 第1509条数据转换出错
# 第1510条数据转换出错
# 第1511条数据转换出错
#   9%|██████▋                                                                     | 1512/17058 [00:05<00:55, 279.67it/s]
# 第1512条数据转换出错
# 第1513条数据转换出错
# 第1514条数据转换出错
# 第1515条数据转换出错
# 第1516条数据转换出错
# 第1517条数据转换出错
# 第1518条数据转换出错
# 第1519条数据转换出错
# 第1520条数据转换出错
# 第1521条数据转换出错
# 第1522条数据转换出错
# 第1523条数据转换出错
# 第1524条数据转换出错
# 第1525条数据转换出错
# 第1526条数据转换出错
# 第1527条数据转换出错
# 第1528条数据转换出错
# 第1529条数据转换出错
# 第1530条数据转换出错
# 第1531条数据转换出错
# 第1532条数据转换出错
# 第1533条数据转换出错
# 第1534条数据转换出错
# 第1535条数据转换出错
# 第1536条数据转换出错
# 第1537条数据转换出错
# 第1538条数据转换出错
# 第1539条数据转换出错
# 第1540条数据转换出错
# 第1541条数据转换出错
#   9%|██████▊                                                                     | 1542/17058 [00:05<00:54, 283.27it/s]
# 第1542条数据转换出错
# 第1543条数据转换出错
# 第1544条数据转换出错
# 第1545条数据转换出错
# 第1546条数据转换出错
# 第1547条数据转换出错
# 第1548条数据转换出错
# 第1549条数据转换出错
# 第1550条数据转换出错
# 第1551条数据转换出错
# 第1552条数据转换出错
# 第1553条数据转换出错
# 第1554条数据转换出错
# 第1555条数据转换出错
# 第1556条数据转换出错
# 第1557条数据转换出错
# 第1558条数据转换出错
# 第1559条数据转换出错
# 第1560条数据转换出错
# 第1561条数据转换出错
# 第1562条数据转换出错
# 第1563条数据转换出错
# 第1564条数据转换出错
# 第1565条数据转换出错
# 第1566条数据转换出错
# 第1567条数据转换出错
# 第1568条数据转换出错
# 第1569条数据转换出错
# 第1570条数据转换出错
# 第1571条数据转换出错
#   9%|███████                                                                     | 1572/17058 [00:05<01:00, 256.59it/s]
# 第1572条数据转换出错
# 第1573条数据转换出错
# 第1574条数据转换出错
# 第1575条数据转换出错
# 第1576条数据转换出错
# 第1577条数据转换出错
# 第1578条数据转换出错
# 第1579条数据转换出错
# 第1580条数据转换出错
# 第1581条数据转换出错
# 第1582条数据转换出错
# 第1583条数据转换出错
# 第1584条数据转换出错
# 第1585条数据转换出错
# 第1586条数据转换出错
# 第1587条数据转换出错
# 第1588条数据转换出错
# 第1589条数据转换出错
# 第1590条数据转换出错
# 第1591条数据转换出错
# 第1592条数据转换出错
# 第1593条数据转换出错
# 第1594条数据转换出错
# 第1595条数据转换出错
# 第1596条数据转换出错
# 第1597条数据转换出错
# 第1598条数据转换出错
# 第1599条数据转换出错
# 第1600条数据转换出错
# 第1601条数据转换出错
#   9%|███████▏                                                                    | 1602/17058 [00:05<00:57, 267.71it/s]
# 第1602条数据转换出错
# 第1603条数据转换出错
# 第1604条数据转换出错
# 第1605条数据转换出错
# 第1606条数据转换出错
# 第1607条数据转换出错
# 第1608条数据转换出错
# 第1609条数据转换出错
# 第1610条数据转换出错
# 第1611条数据转换出错
# 第1612条数据转换出错
# 第1613条数据转换出错
# 第1614条数据转换出错
# 第1615条数据转换出错
# 第1616条数据转换出错
# 第1617条数据转换出错
# 第1618条数据转换出错
# 第1619条数据转换出错
# 第1620条数据转换出错
# 第1621条数据转换出错
# 第1622条数据转换出错
# 第1623条数据转换出错
# 第1624条数据转换出错
# 第1625条数据转换出错
# 第1626条数据转换出错
# 第1627条数据转换出错
# 第1628条数据转换出错
# 第1629条数据转换出错
#  10%|███████▎                                                                    | 1630/17058 [00:05<01:02, 245.82it/s]
# 第1630条数据转换出错
# 第1631条数据转换出错
# 第1632条数据转换出错
# 第1633条数据转换出错
# 第1634条数据转换出错
# 第1635条数据转换出错
# 第1636条数据转换出错
# 第1637条数据转换出错
# 第1638条数据转换出错
# 第1639条数据转换出错
# 第1640条数据转换出错
# 第1641条数据转换出错
# 第1642条数据转换出错
# 第1643条数据转换出错
# 第1644条数据转换出错
# 第1645条数据转换出错
# 第1646条数据转换出错
# 第1647条数据转换出错
# 第1648条数据转换出错
# 第1649条数据转换出错
# 第1650条数据转换出错
# 第1651条数据转换出错
# 第1652条数据转换出错
# 第1653条数据转换出错
# 第1654条数据转换出错
# 第1655条数据转换出错
# 第1656条数据转换出错
# 第1657条数据转换出错
# 第1658条数据转换出错
# 第1659条数据转换出错
# 第1660条数据转换出错
# 第1661条数据转换出错
# 第1662条数据转换出错
# 第1663条数据转换出错
# 第1664条数据转换出错
# 第1665条数据转换出错
# 第1666条数据转换出错
# 第1667条数据转换出错
# 第1668条数据转换出错
# 第1669条数据转换出错
# 第1670条数据转换出错
# 第1671条数据转换出错
# 第1672条数据转换出错
# 第1673条数据转换出错
# 第1674条数据转换出错
# 第1675条数据转换出错
# 第1676条数据转换出错
# 第1677条数据转换出错
# 第1678条数据转换出错
#  10%|███████▍                                                                    | 1679/17058 [00:05<00:53, 287.64it/s]
# 第1679条数据转换出错
# 第1680条数据转换出错
# 第1681条数据转换出错
# 第1682条数据转换出错
# 第1683条数据转换出错
# 第1684条数据转换出错
# 第1685条数据转换出错
# 第1686条数据转换出错
# 第1687条数据转换出错
# 第1688条数据转换出错
# 第1689条数据转换出错
# 第1690条数据转换出错
# 第1691条数据转换出错
# 第1692条数据转换出错
# 第1693条数据转换出错
# 第1694条数据转换出错
# 第1695条数据转换出错
# 第1696条数据转换出错
# 第1697条数据转换出错
# 第1698条数据转换出错
# 第1699条数据转换出错
# 第1700条数据转换出错
# 第1701条数据转换出错
# 第1702条数据转换出错
# 第1703条数据转换出错
# 第1704条数据转换出错
# 第1705条数据转换出错
# 第1706条数据转换出错
# 第1707条数据转换出错
# 第1708条数据转换出错
# 第1709条数据转换出错
# 第1710条数据转换出错
# 第1711条数据转换出错
#  10%|███████▋                                                                    | 1712/17058 [00:05<00:53, 287.66it/s]
# 第1712条数据转换出错
# 第1713条数据转换出错
# 第1714条数据转换出错
# 第1715条数据转换出错
# 第1716条数据转换出错
# 第1717条数据转换出错
# 第1718条数据转换出错
# 第1719条数据转换出错
# 第1720条数据转换出错
# 第1721条数据转换出错
# 第1722条数据转换出错
# 第1723条数据转换出错
# 第1724条数据转换出错
# 第1725条数据转换出错
# 第1726条数据转换出错
# 第1727条数据转换出错
# 第1728条数据转换出错
# 第1729条数据转换出错
# 第1730条数据转换出错
# 第1731条数据转换出错
# 第1732条数据转换出错
# 第1733条数据转换出错
# 第1734条数据转换出错
# 第1735条数据转换出错
# 第1736条数据转换出错
# 第1737条数据转换出错
# 第1738条数据转换出错
# 第1739条数据转换出错
# 第1740条数据转换出错
# 第1741条数据转换出错
# 第1742条数据转换出错
# 第1743条数据转换出错
#  10%|███████▊                                                                    | 1744/17058 [00:05<01:02, 246.86it/s]
# 第1744条数据转换出错
# 第1745条数据转换出错
# 第1746条数据转换出错
# 第1747条数据转换出错
# 第1748条数据转换出错
# 第1749条数据转换出错
# 第1750条数据转换出错
# 第1751条数据转换出错
# 第1752条数据转换出错
# 第1753条数据转换出错
# 第1754条数据转换出错
# 第1755条数据转换出错
# 第1756条数据转换出错
# 第1757条数据转换出错
# 第1758条数据转换出错
# 第1759条数据转换出错
# 第1760条数据转换出错
# 第1761条数据转换出错
# 第1762条数据转换出错
# 第1763条数据转换出错
# 第1764条数据转换出错
# 第1765条数据转换出错
# 第1766条数据转换出错
# 第1767条数据转换出错
# 第1768条数据转换出错
# 第1769条数据转换出错
# 第1770条数据转换出错
# 第1771条数据转换出错
# 第1772条数据转换出错
# 第1773条数据转换出错
#  10%|███████▉                                                                    | 1774/17058 [00:06<01:00, 254.28it/s]
# 第1774条数据转换出错
# 第1775条数据转换出错
# 第1776条数据转换出错
# 第1777条数据转换出错
# 第1778条数据转换出错
# 第1779条数据转换出错
# 第1780条数据转换出错
# 第1781条数据转换出错
# 第1782条数据转换出错
# 第1783条数据转换出错
# 第1784条数据转换出错
# 第1785条数据转换出错
# 第1786条数据转换出错
# 第1787条数据转换出错
# 第1788条数据转换出错
# 第1789条数据转换出错
# 第1790条数据转换出错
# 第1791条数据转换出错
# 第1792条数据转换出错
# 第1793条数据转换出错
# 第1794条数据转换出错
# 第1795条数据转换出错
# 第1796条数据转换出错
# 第1797条数据转换出错
# 第1798条数据转换出错
# 第1799条数据转换出错
# 第1800条数据转换出错
# 第1801条数据转换出错
# 第1802条数据转换出错
# 第1803条数据转换出错
# 第1804条数据转换出错
# 第1805条数据转换出错
#  11%|████████                                                                    | 1806/17058 [00:06<00:56, 270.47it/s]
# 第1806条数据转换出错
# 第1807条数据转换出错
# 第1808条数据转换出错
# 第1809条数据转换出错
# 第1810条数据转换出错
# 第1811条数据转换出错
# 第1812条数据转换出错
# 第1813条数据转换出错
# 第1814条数据转换出错
# 第1815条数据转换出错
# 第1816条数据转换出错
# 第1817条数据转换出错
# 第1818条数据转换出错
# 第1819条数据转换出错
# 第1820条数据转换出错
# 第1821条数据转换出错
# 第1822条数据转换出错
# 第1823条数据转换出错
# 第1824条数据转换出错
# 第1825条数据转换出错
# 第1826条数据转换出错
# 第1827条数据转换出错
# 第1828条数据转换出错
# 第1829条数据转换出错
# 第1830条数据转换出错
# 第1831条数据转换出错
# 第1832条数据转换出错
# 第1833条数据转换出错
# 第1834条数据转换出错
# 第1835条数据转换出错
# 第1836条数据转换出错
# 第1837条数据转换出错
#  11%|████████▏                                                                   | 1838/17058 [00:06<00:53, 282.34it/s]
# 第1838条数据转换出错
# 第1839条数据转换出错
# 第1840条数据转换出错
# 第1841条数据转换出错
# 第1842条数据转换出错
# 第1843条数据转换出错
# 第1844条数据转换出错
# 第1845条数据转换出错
# 第1846条数据转换出错
# 第1847条数据转换出错
# 第1848条数据转换出错
# 第1849条数据转换出错
# 第1850条数据转换出错
# 第1851条数据转换出错
# 第1852条数据转换出错
# 第1853条数据转换出错
# 第1854条数据转换出错
# 第1855条数据转换出错
# 第1856条数据转换出错
# 第1857条数据转换出错
# 第1858条数据转换出错
# 第1859条数据转换出错
# 第1860条数据转换出错
# 第1861条数据转换出错
# 第1862条数据转换出错
# 第1863条数据转换出错
# 第1864条数据转换出错
# 第1865条数据转换出错
# 第1866条数据转换出错
# 第1867条数据转换出错
# 第1868条数据转换出错
# 第1869条数据转换出错
# 第1870条数据转换出错
# 第1871条数据转换出错
# 第1872条数据转换出错
# 第1873条数据转换出错
# 第1874条数据转换出错
# 第1875条数据转换出错
# 第1876条数据转换出错
# 第1877条数据转换出错
# 第1878条数据转换出错
# 第1879条数据转换出错
# 第1880条数据转换出错
#  11%|████████▍                                                                   | 1881/17058 [00:06<00:48, 314.27it/s]
# 第1881条数据转换出错
# 第1882条数据转换出错
# 第1883条数据转换出错
# 第1884条数据转换出错
# 第1885条数据转换出错
# 第1886条数据转换出错
# 第1887条数据转换出错
# 第1888条数据转换出错
# 第1889条数据转换出错
# 第1890条数据转换出错
# 第1891条数据转换出错
# 第1892条数据转换出错
# 第1893条数据转换出错
# 第1894条数据转换出错
# 第1895条数据转换出错
# 第1896条数据转换出错
# 第1897条数据转换出错
# 第1898条数据转换出错
# 第1899条数据转换出错
# 第1900条数据转换出错
# 第1901条数据转换出错
# 第1902条数据转换出错
# 第1903条数据转换出错
# 第1904条数据转换出错
# 第1905条数据转换出错
# 第1906条数据转换出错
# 第1907条数据转换出错
# 第1908条数据转换出错
# 第1909条数据转换出错
# 第1910条数据转换出错
# 第1911条数据转换出错
# 第1912条数据转换出错
# 第1913条数据转换出错
# 第1914条数据转换出错
#  11%|████████▌                                                                   | 1915/17058 [00:06<00:54, 278.42it/s]
# 第1915条数据转换出错
# 第1916条数据转换出错
# 第1917条数据转换出错
# 第1918条数据转换出错
# 第1919条数据转换出错
# 第1920条数据转换出错
# 第1921条数据转换出错
# 第1922条数据转换出错
# 第1923条数据转换出错
# 第1924条数据转换出错
# 第1925条数据转换出错
# 第1926条数据转换出错
# 第1927条数据转换出错
# 第1928条数据转换出错
# 第1929条数据转换出错
# 第1930条数据转换出错
# 第1931条数据转换出错
# 第1932条数据转换出错
# 第1933条数据转换出错
# 第1934条数据转换出错
# 第1935条数据转换出错
# 第1936条数据转换出错
# 第1937条数据转换出错
# 第1938条数据转换出错
# 第1939条数据转换出错
# 第1940条数据转换出错
# 第1941条数据转换出错
# 第1942条数据转换出错
# 第1943条数据转换出错
# 第1944条数据转换出错
# 第1945条数据转换出错
#  11%|████████▋                                                                   | 1946/17058 [00:06<00:56, 268.79it/s]
# 第1946条数据转换出错
# 第1947条数据转换出错
# 第1948条数据转换出错
# 第1949条数据转换出错
# 第1950条数据转换出错
# 第1951条数据转换出错
# 第1952条数据转换出错
# 第1953条数据转换出错
# 第1954条数据转换出错
# 第1955条数据转换出错
# 第1956条数据转换出错
# 第1957条数据转换出错
# 第1958条数据转换出错
# 第1959条数据转换出错
# 第1960条数据转换出错
# 第1961条数据转换出错
# 第1962条数据转换出错
# 第1963条数据转换出错
# 第1964条数据转换出错
# 第1965条数据转换出错
# 第1966条数据转换出错
# 第1967条数据转换出错
# 第1968条数据转换出错
# 第1969条数据转换出错
# 第1970条数据转换出错
# 第1971条数据转换出错
# 第1972条数据转换出错
# 第1973条数据转换出错
# 第1974条数据转换出错
# 第1975条数据转换出错
# 第1976条数据转换出错
# 第1977条数据转换出错
# 第1978条数据转换出错
# 第1979条数据转换出错
#  12%|████████▊                                                                   | 1980/17058 [00:06<00:52, 286.28it/s]
# 第1980条数据转换出错
# 第1981条数据转换出错
# 第1982条数据转换出错
# 第1983条数据转换出错
# 第1984条数据转换出错
# 第1985条数据转换出错
# 第1986条数据转换出错
# 第1987条数据转换出错
# 第1988条数据转换出错
# 第1989条数据转换出错
# 第1990条数据转换出错
# 第1991条数据转换出错
# 第1992条数据转换出错
# 第1993条数据转换出错
# 第1994条数据转换出错
# 第1995条数据转换出错
# 第1996条数据转换出错
# 第1997条数据转换出错
# 第1998条数据转换出错
# 第1999条数据转换出错
# 第2000条数据转换出错
# 第2001条数据转换出错
# 第2002条数据转换出错
# 第2003条数据转换出错
# 第2004条数据转换出错
# 第2005条数据转换出错
# 第2006条数据转换出错
# 第2007条数据转换出错
# 第2008条数据转换出错
# 第2009条数据转换出错
# 第2010条数据转换出错
#  12%|████████▉                                                                   | 2011/17058 [00:06<00:54, 278.25it/s]
# 第2011条数据转换出错
# 第2012条数据转换出错
# 第2013条数据转换出错
# 第2014条数据转换出错
# 第2015条数据转换出错
# 第2016条数据转换出错
# 第2017条数据转换出错
# 第2018条数据转换出错
# 第2019条数据转换出错
# 第2020条数据转换出错
# 第2021条数据转换出错
# 第2022条数据转换出错
# 第2023条数据转换出错
# 第2024条数据转换出错
# 第2025条数据转换出错
# 第2026条数据转换出错
# 第2027条数据转换出错
# 第2028条数据转换出错
# 第2029条数据转换出错
# 第2030条数据转换出错
# 第2031条数据转换出错
# 第2032条数据转换出错
# 第2033条数据转换出错
# 第2034条数据转换出错
# 第2035条数据转换出错
# 第2036条数据转换出错
# 第2037条数据转换出错
# 第2038条数据转换出错
# 第2039条数据转换出错
#  12%|█████████                                                                   | 2040/17058 [00:06<00:54, 276.29it/s]
# 第2040条数据转换出错
# 第2041条数据转换出错
# 第2042条数据转换出错
# 第2043条数据转换出错
# 第2044条数据转换出错
# 第2045条数据转换出错
# 第2046条数据转换出错
# 第2047条数据转换出错
# 第2048条数据转换出错
# 第2049条数据转换出错
# 第2050条数据转换出错
# 第2051条数据转换出错
# 第2052条数据转换出错
# 第2053条数据转换出错
# 第2054条数据转换出错
# 第2055条数据转换出错
# 第2056条数据转换出错
# 第2057条数据转换出错
# 第2058条数据转换出错
# 第2059条数据转换出错
# 第2060条数据转换出错
# 第2061条数据转换出错
# 第2062条数据转换出错
# 第2063条数据转换出错
# 第2064条数据转换出错
# 第2065条数据转换出错
# 第2066条数据转换出错
# 第2067条数据转换出错
# 第2068条数据转换出错
#  12%|█████████▏                                                                  | 2069/17058 [00:07<00:55, 271.07it/s]
# 第2069条数据转换出错
# 第2070条数据转换出错
# 第2071条数据转换出错
# 第2072条数据转换出错
# 第2073条数据转换出错
# 第2074条数据转换出错
# 第2075条数据转换出错
# 第2076条数据转换出错
# 第2077条数据转换出错
# 第2078条数据转换出错
# 第2079条数据转换出错
# 第2080条数据转换出错
# 第2081条数据转换出错
# 第2082条数据转换出错
# 第2083条数据转换出错
# 第2084条数据转换出错
# 第2085条数据转换出错
# 第2086条数据转换出错
# 第2087条数据转换出错
# 第2088条数据转换出错
# 第2089条数据转换出错
# 第2090条数据转换出错
# 第2091条数据转换出错
# 第2092条数据转换出错
# 第2093条数据转换出错
# 第2094条数据转换出错
# 第2095条数据转换出错
# 第2096条数据转换出错
# 第2097条数据转换出错
# 第2098条数据转换出错
# 第2099条数据转换出错
# 第2100条数据转换出错
# 第2101条数据转换出错
# 第2102条数据转换出错
# 第2103条数据转换出错
# 第2104条数据转换出错
# 第2105条数据转换出错
# 第2106条数据转换出错
# 第2107条数据转换出错
# 第2108条数据转换出错
# 第2109条数据转换出错
# 第2110条数据转换出错
# 第2111条数据转换出错
# 第2112条数据转换出错
#  12%|█████████▍                                                                  | 2113/17058 [00:07<00:48, 305.89it/s]
# 第2113条数据转换出错
# 第2114条数据转换出错
# 第2115条数据转换出错
# 第2116条数据转换出错
# 第2117条数据转换出错
# 第2118条数据转换出错
# 第2119条数据转换出错
# 第2120条数据转换出错
# 第2121条数据转换出错
# 第2122条数据转换出错
# 第2123条数据转换出错
# 第2124条数据转换出错
# 第2125条数据转换出错
# 第2126条数据转换出错
# 第2127条数据转换出错
# 第2128条数据转换出错
# 第2129条数据转换出错
# 第2130条数据转换出错
# 第2131条数据转换出错
# 第2132条数据转换出错
# 第2133条数据转换出错
# 第2134条数据转换出错
# 第2135条数据转换出错
# 第2136条数据转换出错
# 第2137条数据转换出错
# 第2138条数据转换出错
# 第2139条数据转换出错
# 第2140条数据转换出错
# 第2141条数据转换出错
# 第2142条数据转换出错
# 第2143条数据转换出错
# 第2144条数据转换出错
# 第2145条数据转换出错
#  13%|█████████▌                                                                  | 2146/17058 [00:07<00:56, 265.51it/s]
# 第2146条数据转换出错
# 第2147条数据转换出错
# 第2148条数据转换出错
# 第2149条数据转换出错
# 第2150条数据转换出错
# 第2151条数据转换出错
# 第2152条数据转换出错
# 第2153条数据转换出错
# 第2154条数据转换出错
# 第2155条数据转换出错
# 第2156条数据转换出错
# 第2157条数据转换出错
# 第2158条数据转换出错
# 第2159条数据转换出错
# 第2160条数据转换出错
# 第2161条数据转换出错
# 第2162条数据转换出错
# 第2163条数据转换出错
# 第2164条数据转换出错
# 第2165条数据转换出错
# 第2166条数据转换出错
# 第2167条数据转换出错
# 第2168条数据转换出错
# 第2169条数据转换出错
# 第2170条数据转换出错
# 第2171条数据转换出错
# 第2172条数据转换出错
# 第2173条数据转换出错
# 第2174条数据转换出错
#  13%|█████████▋                                                                  | 2175/17058 [00:07<00:57, 260.88it/s]
# 第2175条数据转换出错
# 第2176条数据转换出错
# 第2177条数据转换出错
# 第2178条数据转换出错
# 第2179条数据转换出错
# 第2180条数据转换出错
# 第2181条数据转换出错
# 第2182条数据转换出错
# 第2183条数据转换出错
# 第2184条数据转换出错
# 第2185条数据转换出错
# 第2186条数据转换出错
# 第2187条数据转换出错
# 第2188条数据转换出错
# 第2189条数据转换出错
# 第2190条数据转换出错
# 第2191条数据转换出错
# 第2192条数据转换出错
# 第2193条数据转换出错
# 第2194条数据转换出错
# 第2195条数据转换出错
# 第2196条数据转换出错
# 第2197条数据转换出错
# 第2198条数据转换出错
# 第2199条数据转换出错
# 第2200条数据转换出错
# 第2201条数据转换出错
# 第2202条数据转换出错
# 第2203条数据转换出错
# 第2204条数据转换出错
# 第2205条数据转换出错
# 第2206条数据转换出错
# 第2207条数据转换出错
# 第2208条数据转换出错
# 第2209条数据转换出错
# 第2210条数据转换出错
# 第2211条数据转换出错
# 第2212条数据转换出错
# 第2213条数据转换出错
# 第2214条数据转换出错
#  13%|█████████▊                                                                  | 2215/17058 [00:07<00:51, 290.17it/s]
# 第2215条数据转换出错
# 第2216条数据转换出错
# 第2217条数据转换出错
# 第2218条数据转换出错
# 第2219条数据转换出错
# 第2220条数据转换出错
# 第2221条数据转换出错
# 第2222条数据转换出错
# 第2223条数据转换出错
# 第2224条数据转换出错
# 第2225条数据转换出错
# 第2226条数据转换出错
# 第2227条数据转换出错
# 第2228条数据转换出错
# 第2229条数据转换出错
# 第2230条数据转换出错
# 第2231条数据转换出错
# 第2232条数据转换出错
# 第2233条数据转换出错
# 第2234条数据转换出错
# 第2235条数据转换出错
# 第2236条数据转换出错
# 第2237条数据转换出错
# 第2238条数据转换出错
# 第2239条数据转换出错
# 第2240条数据转换出错
# 第2241条数据转换出错
# 第2242条数据转换出错
# 第2243条数据转换出错
# 第2244条数据转换出错
# 第2245条数据转换出错
# 第2246条数据转换出错
# 第2247条数据转换出错
# 第2248条数据转换出错
# 第2249条数据转换出错
#  13%|██████████                                                                  | 2250/17058 [00:07<00:48, 305.27it/s]
# 第2250条数据转换出错
# 第2251条数据转换出错
# 第2252条数据转换出错
# 第2253条数据转换出错
# 第2254条数据转换出错
# 第2255条数据转换出错
# 第2256条数据转换出错
# 第2257条数据转换出错
# 第2258条数据转换出错
# 第2259条数据转换出错
# 第2260条数据转换出错
# 第2261条数据转换出错
# 第2262条数据转换出错
# 第2263条数据转换出错
# 第2264条数据转换出错
# 第2265条数据转换出错
# 第2266条数据转换出错
# 第2267条数据转换出错
# 第2268条数据转换出错
# 第2269条数据转换出错
# 第2270条数据转换出错
# 第2271条数据转换出错
# 第2272条数据转换出错
# 第2273条数据转换出错
# 第2274条数据转换出错
# 第2275条数据转换出错
# 第2276条数据转换出错
# 第2277条数据转换出错
# 第2278条数据转换出错
# 第2279条数据转换出错
# 第2280条数据转换出错
# 第2281条数据转换出错
# 第2282条数据转换出错
#  13%|██████████▏                                                                 | 2283/17058 [00:07<00:53, 273.75it/s]
# 第2283条数据转换出错
# 第2284条数据转换出错
# 第2285条数据转换出错
# 第2286条数据转换出错
# 第2287条数据转换出错
# 第2288条数据转换出错
# 第2289条数据转换出错
# 第2290条数据转换出错
# 第2291条数据转换出错
# 第2292条数据转换出错
# 第2293条数据转换出错
# 第2294条数据转换出错
# 第2295条数据转换出错
# 第2296条数据转换出错
# 第2297条数据转换出错
# 第2298条数据转换出错
# 第2299条数据转换出错
# 第2300条数据转换出错
# 第2301条数据转换出错
# 第2302条数据转换出错
# 第2303条数据转换出错
# 第2304条数据转换出错
# 第2305条数据转换出错
# 第2306条数据转换出错
# 第2307条数据转换出错
# 第2308条数据转换出错
# 第2309条数据转换出错
# 第2310条数据转换出错
# 第2311条数据转换出错
# 第2312条数据转换出错
# 第2313条数据转换出错
# 第2314条数据转换出错
# 第2315条数据转换出错
# 第2316条数据转换出错
# 第2317条数据转换出错
# 第2318条数据转换出错
# 第2319条数据转换出错
# 第2320条数据转换出错
# 第2321条数据转换出错
# 第2322条数据转换出错
# 第2323条数据转换出错
# 第2324条数据转换出错
#  14%|██████████▎                                                                 | 2325/17058 [00:07<00:48, 304.53it/s]
# 第2325条数据转换出错
# 第2326条数据转换出错
# 第2327条数据转换出错
# 第2328条数据转换出错
# 第2329条数据转换出错
# 第2330条数据转换出错
# 第2331条数据转换出错
# 第2332条数据转换出错
# 第2333条数据转换出错
# 第2334条数据转换出错
# 第2335条数据转换出错
# 第2336条数据转换出错
# 第2337条数据转换出错
# 第2338条数据转换出错
# 第2339条数据转换出错
# 第2340条数据转换出错
# 第2341条数据转换出错
# 第2342条数据转换出错
# 第2343条数据转换出错
# 第2344条数据转换出错
# 第2345条数据转换出错
# 第2346条数据转换出错
# 第2347条数据转换出错
# 第2348条数据转换出错
# 第2349条数据转换出错
# 第2350条数据转换出错
# 第2351条数据转换出错
# 第2352条数据转换出错
# 第2353条数据转换出错
# 第2354条数据转换出错
# 第2355条数据转换出错
# 第2356条数据转换出错
# 第2357条数据转换出错
#  14%|██████████▌                                                                 | 2358/17058 [00:08<00:48, 305.08it/s]
# 第2358条数据转换出错
# 第2359条数据转换出错
# 第2360条数据转换出错
# 第2361条数据转换出错
# 第2362条数据转换出错
# 第2363条数据转换出错
# 第2364条数据转换出错
# 第2365条数据转换出错
# 第2366条数据转换出错
# 第2367条数据转换出错
# 第2368条数据转换出错
# 第2369条数据转换出错
# 第2370条数据转换出错
# 第2371条数据转换出错
# 第2372条数据转换出错
# 第2373条数据转换出错
# 第2374条数据转换出错
# 第2375条数据转换出错
# 第2376条数据转换出错
# 第2377条数据转换出错
# 第2378条数据转换出错
# 第2379条数据转换出错
# 第2380条数据转换出错
# 第2381条数据转换出错
# 第2382条数据转换出错
# 第2383条数据转换出错
# 第2384条数据转换出错
# 第2385条数据转换出错
# 第2386条数据转换出错
# 第2387条数据转换出错
# 第2388条数据转换出错
# 第2389条数据转换出错
# 第2390条数据转换出错
#  14%|██████████▋                                                                 | 2391/17058 [00:08<00:51, 284.19it/s]
# 第2391条数据转换出错
# 第2392条数据转换出错
# 第2393条数据转换出错
# 第2394条数据转换出错
# 第2395条数据转换出错
# 第2396条数据转换出错
# 第2397条数据转换出错
# 第2398条数据转换出错
# 第2399条数据转换出错
# 第2400条数据转换出错
# 第2401条数据转换出错
# 第2402条数据转换出错
# 第2403条数据转换出错
# 第2404条数据转换出错
# 第2405条数据转换出错
# 第2406条数据转换出错
# 第2407条数据转换出错
# 第2408条数据转换出错
# 第2409条数据转换出错
# 第2410条数据转换出错
# 第2411条数据转换出错
# 第2412条数据转换出错
# 第2413条数据转换出错
# 第2414条数据转换出错
# 第2415条数据转换出错
# 第2416条数据转换出错
# 第2417条数据转换出错
# 第2418条数据转换出错
# 第2419条数据转换出错
# 第2420条数据转换出错
#  14%|██████████▊                                                                 | 2421/17058 [00:08<00:50, 287.35it/s]
# 第2421条数据转换出错
# 第2422条数据转换出错
# 第2423条数据转换出错
# 第2424条数据转换出错
# 第2425条数据转换出错
# 第2426条数据转换出错
# 第2427条数据转换出错
# 第2428条数据转换出错
# 第2429条数据转换出错
# 第2430条数据转换出错
# 第2431条数据转换出错
# 第2432条数据转换出错
# 第2433条数据转换出错
# 第2434条数据转换出错
# 第2435条数据转换出错
# 第2436条数据转换出错
# 第2437条数据转换出错
# 第2438条数据转换出错
# 第2439条数据转换出错
# 第2440条数据转换出错
# 第2441条数据转换出错
# 第2442条数据转换出错
# 第2443条数据转换出错
# 第2444条数据转换出错
# 第2445条数据转换出错
# 第2446条数据转换出错
# 第2447条数据转换出错
# 第2448条数据转换出错
# 第2449条数据转换出错
# 第2450条数据转换出错
#  14%|██████████▉                                                                 | 2451/17058 [00:08<00:53, 271.54it/s]
# 第2451条数据转换出错
# 第2452条数据转换出错
# 第2453条数据转换出错
# 第2454条数据转换出错
# 第2455条数据转换出错
# 第2456条数据转换出错
# 第2457条数据转换出错
# 第2458条数据转换出错
# 第2459条数据转换出错
# 第2460条数据转换出错
# 第2461条数据转换出错
# 第2462条数据转换出错
# 第2463条数据转换出错
# 第2464条数据转换出错
# 第2465条数据转换出错
# 第2466条数据转换出错
# 第2467条数据转换出错
# 第2468条数据转换出错
# 第2469条数据转换出错
# 第2470条数据转换出错
# 第2471条数据转换出错
# 第2472条数据转换出错
# 第2473条数据转换出错
# 第2474条数据转换出错
# 第2475条数据转换出错
# 第2476条数据转换出错
# 第2477条数据转换出错
# 第2478条数据转换出错
# 第2479条数据转换出错
# 第2480条数据转换出错
# 第2481条数据转换出错
#  15%|███████████                                                                 | 2482/17058 [00:08<00:52, 279.95it/s]
# 第2482条数据转换出错
# 第2483条数据转换出错
# 第2484条数据转换出错
# 第2485条数据转换出错
# 第2486条数据转换出错
# 第2487条数据转换出错
# 第2488条数据转换出错
# 第2489条数据转换出错
# 第2490条数据转换出错
# 第2491条数据转换出错
# 第2492条数据转换出错
# 第2493条数据转换出错
# 第2494条数据转换出错
# 第2495条数据转换出错
# 第2496条数据转换出错
# 第2497条数据转换出错
# 第2498条数据转换出错
# 第2499条数据转换出错
# 第2500条数据转换出错
# 第2501条数据转换出错
# 第2502条数据转换出错
# 第2503条数据转换出错
# 第2504条数据转换出错
# 第2505条数据转换出错
# 第2506条数据转换出错
# 第2507条数据转换出错
# 第2508条数据转换出错
# 第2509条数据转换出错
# 第2510条数据转换出错
#  15%|███████████▏                                                                | 2511/17058 [00:08<00:51, 281.47it/s]
# 第2511条数据转换出错
# 第2512条数据转换出错
# 第2513条数据转换出错
# 第2514条数据转换出错
# 第2515条数据转换出错
# 第2516条数据转换出错
# 第2517条数据转换出错
# 第2518条数据转换出错
# 第2519条数据转换出错
# 第2520条数据转换出错
# 第2521条数据转换出错
# 第2522条数据转换出错
# 第2523条数据转换出错
# 第2524条数据转换出错
# 第2525条数据转换出错
# 第2526条数据转换出错
# 第2527条数据转换出错
# 第2528条数据转换出错
# 第2529条数据转换出错
# 第2530条数据转换出错
# 第2531条数据转换出错
# 第2532条数据转换出错
# 第2533条数据转换出错
# 第2534条数据转换出错
# 第2535条数据转换出错
# 第2536条数据转换出错
# 第2537条数据转换出错
# 第2538条数据转换出错
# 第2539条数据转换出错
# 第2540条数据转换出错
# 第2541条数据转换出错
# 第2542条数据转换出错
# 第2543条数据转换出错
# 第2544条数据转换出错
# 第2545条数据转换出错
# 第2546条数据转换出错
# 第2547条数据转换出错
# 第2548条数据转换出错
# 第2549条数据转换出错
# 第2550条数据转换出错
# 第2551条数据转换出错
# 第2552条数据转换出错
# 第2553条数据转换出错
# 第2554条数据转换出错
# 第2555条数据转换出错
# 第2556条数据转换出错
# 第2557条数据转换出错
# 第2558条数据转换出错
# 第2559条数据转换出错
# 第2560条数据转换出错
# 第2561条数据转换出错
#  15%|███████████▍                                                                | 2562/17058 [00:08<00:44, 322.89it/s]
# 第2562条数据转换出错
# 第2563条数据转换出错
# 第2564条数据转换出错
# 第2565条数据转换出错
# 第2566条数据转换出错
# 第2567条数据转换出错
# 第2568条数据转换出错
# 第2569条数据转换出错
# 第2570条数据转换出错
# 第2571条数据转换出错
# 第2572条数据转换出错
# 第2573条数据转换出错
# 第2574条数据转换出错
# 第2575条数据转换出错
# 第2576条数据转换出错
# 第2577条数据转换出错
# 第2578条数据转换出错
# 第2579条数据转换出错
# 第2580条数据转换出错
# 第2581条数据转换出错
# 第2582条数据转换出错
# 第2583条数据转换出错
# 第2584条数据转换出错
# 第2585条数据转换出错
# 第2586条数据转换出错
# 第2587条数据转换出错
# 第2588条数据转换出错
# 第2589条数据转换出错
# 第2590条数据转换出错
# 第2591条数据转换出错
# 第2592条数据转换出错
# 第2593条数据转换出错
# 第2594条数据转换出错
# 第2595条数据转换出错
# 第2596条数据转换出错
#  15%|███████████▌                                                                | 2597/17058 [00:08<00:53, 269.78it/s]
# 第2597条数据转换出错
# 第2598条数据转换出错
# 第2599条数据转换出错
# 第2600条数据转换出错
# 第2601条数据转换出错
# 第2602条数据转换出错
# 第2603条数据转换出错
# 第2604条数据转换出错
# 第2605条数据转换出错
# 第2606条数据转换出错
# 第2607条数据转换出错
# 第2608条数据转换出错
# 第2609条数据转换出错
# 第2610条数据转换出错
# 第2611条数据转换出错
# 第2612条数据转换出错
# 第2613条数据转换出错
# 第2614条数据转换出错
# 第2615条数据转换出错
# 第2616条数据转换出错
# 第2617条数据转换出错
# 第2618条数据转换出错
# 第2619条数据转换出错
# 第2620条数据转换出错
# 第2621条数据转换出错
# 第2622条数据转换出错
# 第2623条数据转换出错
# 第2624条数据转换出错
# 第2625条数据转换出错
# 第2626条数据转换出错
# 第2627条数据转换出错
# 第2628条数据转换出错
# 第2629条数据转换出错
# 第2630条数据转换出错
# 第2631条数据转换出错
# 第2632条数据转换出错
# 第2633条数据转换出错
# 第2634条数据转换出错
# 第2635条数据转换出错
# 第2636条数据转换出错
# 第2637条数据转换出错
# 第2638条数据转换出错
#  15%|███████████▊                                                                | 2639/17058 [00:08<00:47, 301.73it/s]
# 第2639条数据转换出错
# 第2640条数据转换出错
# 第2641条数据转换出错
# 第2642条数据转换出错
# 第2643条数据转换出错
# 第2644条数据转换出错
# 第2645条数据转换出错
# 第2646条数据转换出错
# 第2647条数据转换出错
# 第2648条数据转换出错
# 第2649条数据转换出错
# 第2650条数据转换出错
# 第2651条数据转换出错
# 第2652条数据转换出错
# 第2653条数据转换出错
# 第2654条数据转换出错
# 第2655条数据转换出错
# 第2656条数据转换出错
# 第2657条数据转换出错
# 第2658条数据转换出错
# 第2659条数据转换出错
# 第2660条数据转换出错
# 第2661条数据转换出错
# 第2662条数据转换出错
# 第2663条数据转换出错
# 第2664条数据转换出错
# 第2665条数据转换出错
# 第2666条数据转换出错
# 第2667条数据转换出错
# 第2668条数据转换出错
# 第2669条数据转换出错
# 第2670条数据转换出错
# 第2671条数据转换出错
# 第2672条数据转换出错
#  16%|███████████▉                                                                | 2673/17058 [00:09<00:50, 282.24it/s]
# 第2673条数据转换出错
# 第2674条数据转换出错
# 第2675条数据转换出错
# 第2676条数据转换出错
# 第2677条数据转换出错
# 第2678条数据转换出错
# 第2679条数据转换出错
# 第2680条数据转换出错
# 第2681条数据转换出错
# 第2682条数据转换出错
# 第2683条数据转换出错
# 第2684条数据转换出错
# 第2685条数据转换出错
# 第2686条数据转换出错
# 第2687条数据转换出错
# 第2688条数据转换出错
# 第2689条数据转换出错
# 第2690条数据转换出错
# 第2691条数据转换出错
# 第2692条数据转换出错
# 第2693条数据转换出错
# 第2694条数据转换出错
# 第2695条数据转换出错
# 第2696条数据转换出错
# 第2697条数据转换出错
# 第2698条数据转换出错
# 第2699条数据转换出错
# 第2700条数据转换出错
# 第2701条数据转换出错
# 第2702条数据转换出错
# 第2703条数据转换出错
#  16%|████████████                                                                | 2704/17058 [00:09<00:55, 259.69it/s]
# 第2704条数据转换出错
# 第2705条数据转换出错
# 第2706条数据转换出错
# 第2707条数据转换出错
# 第2708条数据转换出错
# 第2709条数据转换出错
# 第2710条数据转换出错
# 第2711条数据转换出错
# 第2712条数据转换出错
# 第2713条数据转换出错
# 第2714条数据转换出错
# 第2715条数据转换出错
# 第2716条数据转换出错
# 第2717条数据转换出错
# 第2718条数据转换出错
# 第2719条数据转换出错
# 第2720条数据转换出错
# 第2721条数据转换出错
# 第2722条数据转换出错
# 第2723条数据转换出错
# 第2724条数据转换出错
# 第2725条数据转换出错
# 第2726条数据转换出错
# 第2727条数据转换出错
# 第2728条数据转换出错
# 第2729条数据转换出错
# 第2730条数据转换出错
# 第2731条数据转换出错
# 第2732条数据转换出错
# 第2733条数据转换出错
# 第2734条数据转换出错
# 第2735条数据转换出错
# 第2736条数据转换出错
# 第2737条数据转换出错
# 第2738条数据转换出错
# 第2739条数据转换出错
#  16%|████████████▏                                                               | 2740/17058 [00:09<00:50, 282.89it/s]
# 第2740条数据转换出错
# 第2741条数据转换出错
# 第2742条数据转换出错
# 第2743条数据转换出错
# 第2744条数据转换出错
# 第2745条数据转换出错
# 第2746条数据转换出错
# 第2747条数据转换出错
# 第2748条数据转换出错
# 第2749条数据转换出错
# 第2750条数据转换出错
# 第2751条数据转换出错
# 第2752条数据转换出错
# 第2753条数据转换出错
# 第2754条数据转换出错
# 第2755条数据转换出错
# 第2756条数据转换出错
# 第2757条数据转换出错
# 第2758条数据转换出错
# 第2759条数据转换出错
# 第2760条数据转换出错
# 第2761条数据转换出错
# 第2762条数据转换出错
# 第2763条数据转换出错
# 第2764条数据转换出错
# 第2765条数据转换出错
# 第2766条数据转换出错
# 第2767条数据转换出错
# 第2768条数据转换出错
# 第2769条数据转换出错
# 第2770条数据转换出错
#  16%|████████████▎                                                               | 2771/17058 [00:09<00:49, 287.48it/s]
# 第2771条数据转换出错
# 第2772条数据转换出错
# 第2773条数据转换出错
# 第2774条数据转换出错
# 第2775条数据转换出错
# 第2776条数据转换出错
# 第2777条数据转换出错
# 第2778条数据转换出错
# 第2779条数据转换出错
# 第2780条数据转换出错
# 第2781条数据转换出错
# 第2782条数据转换出错
# 第2783条数据转换出错
# 第2784条数据转换出错
# 第2785条数据转换出错
# 第2786条数据转换出错
# 第2787条数据转换出错
# 第2788条数据转换出错
# 第2789条数据转换出错
# 第2790条数据转换出错
# 第2791条数据转换出错
# 第2792条数据转换出错
# 第2793条数据转换出错
# 第2794条数据转换出错
# 第2795条数据转换出错
# 第2796条数据转换出错
# 第2797条数据转换出错
# 第2798条数据转换出错
# 第2799条数据转换出错
# 第2800条数据转换出错
# 第2801条数据转换出错
#  16%|████████████▍                                                               | 2802/17058 [00:09<00:52, 269.64it/s]
# ...
# 第16203条数据转换出错
# 第16204条数据转换出错
# 第16205条数据转换出错
# 第16206条数据转换出错
# 第16207条数据转换出错
# 第16208条数据转换出错
# 第16209条数据转换出错
# 第16210条数据转换出错
# 第16211条数据转换出错
# 第16212条数据转换出错
# 第16213条数据转换出错
# 第16214条数据转换出错
# 第16215条数据转换出错
# 第16216条数据转换出错
# 第16217条数据转换出错
# 第16218条数据转换出错
# 第16219条数据转换出错
# 第16220条数据转换出错
# 第16221条数据转换出错
# 第16222条数据转换出错
# 第16223条数据转换出错
# 第16224条数据转换出错
# 第16225条数据转换出错
# 第16226条数据转换出错
# 第16227条数据转换出错
# 第16228条数据转换出错
# 第16229条数据转换出错
# 第16230条数据转换出错
# 第16231条数据转换出错
# 第16232条数据转换出错
# 第16233条数据转换出错
# 第16234条数据转换出错
#  95%|███████████████████████████████████████████████████████████████████████▍   | 16235/17058 [00:56<00:02, 296.07it/s]
# 第16235条数据转换出错
# 第16236条数据转换出错
# 第16237条数据转换出错
# 第16238条数据转换出错
# 第16239条数据转换出错
# 第16240条数据转换出错
# 第16241条数据转换出错
# 第16242条数据转换出错
# 第16243条数据转换出错
# 第16244条数据转换出错
# 第16245条数据转换出错
# 第16246条数据转换出错
# 第16247条数据转换出错
# 第16248条数据转换出错
# 第16249条数据转换出错
# 第16250条数据转换出错
# 第16251条数据转换出错
# 第16252条数据转换出错
# 第16253条数据转换出错
# 第16254条数据转换出错
# 第16255条数据转换出错
# 第16256条数据转换出错
# 第16257条数据转换出错
# 第16258条数据转换出错
# 第16259条数据转换出错
# 第16260条数据转换出错
# 第16261条数据转换出错
# 第16262条数据转换出错
# 第16263条数据转换出错
# 第16264条数据转换出错
# 第16265条数据转换出错
# 第16266条数据转换出错
#  95%|███████████████████████████████████████████████████████████████████████▌   | 16267/17058 [00:56<00:02, 277.17it/s]
# 第16267条数据转换出错
# 第16268条数据转换出错
# 第16269条数据转换出错
# 第16270条数据转换出错
# 第16271条数据转换出错
# 第16272条数据转换出错
# 第16273条数据转换出错
# 第16274条数据转换出错
# 第16275条数据转换出错
# 第16276条数据转换出错
# 第16277条数据转换出错
# 第16278条数据转换出错
# 第16279条数据转换出错
# 第16280条数据转换出错
# 第16281条数据转换出错
# 第16282条数据转换出错
# 第16283条数据转换出错
# 第16284条数据转换出错
# 第16285条数据转换出错
# 第16286条数据转换出错
# 第16287条数据转换出错
# 第16288条数据转换出错
# 第16289条数据转换出错
# 第16290条数据转换出错
# 第16291条数据转换出错
# 第16292条数据转换出错
# 第16293条数据转换出错
# 第16294条数据转换出错
# 第16295条数据转换出错
# 第16296条数据转换出错
#  96%|███████████████████████████████████████████████████████████████████████▋   | 16297/17058 [00:56<00:02, 261.64it/s]
# 第16297条数据转换出错
# 第16298条数据转换出错
# 第16299条数据转换出错
# 第16300条数据转换出错
# 第16301条数据转换出错
# 第16302条数据转换出错
# 第16303条数据转换出错
# 第16304条数据转换出错
# 第16305条数据转换出错
# 第16306条数据转换出错
# 第16307条数据转换出错
# 第16308条数据转换出错
# 第16309条数据转换出错
# 第16310条数据转换出错
# 第16311条数据转换出错
# 第16312条数据转换出错
# 第16313条数据转换出错
# 第16314条数据转换出错
# 第16315条数据转换出错
# 第16316条数据转换出错
# 第16317条数据转换出错
# 第16318条数据转换出错
# 第16319条数据转换出错
# 第16320条数据转换出错
# 第16321条数据转换出错
# 第16322条数据转换出错
# 第16323条数据转换出错
# 第16324条数据转换出错
# 第16325条数据转换出错
# 第16326条数据转换出错
# 第16327条数据转换出错
# 第16328条数据转换出错
# 第16329条数据转换出错
# 第16330条数据转换出错
# 第16331条数据转换出错
# 第16332条数据转换出错
# 第16333条数据转换出错
# 第16334条数据转换出错
# 第16335条数据转换出错
# 第16336条数据转换出错
# 第16337条数据转换出错
# 第16338条数据转换出错
# 第16339条数据转换出错
# 第16340条数据转换出错
# 第16341条数据转换出错
# 第16342条数据转换出错
# 第16343条数据转换出错
# 第16344条数据转换出错
# 第16345条数据转换出错
# 第16346条数据转换出错
# 第16347条数据转换出错
#  96%|███████████████████████████████████████████████████████████████████████▉   | 16348/17058 [00:56<00:02, 304.36it/s]
# 第16348条数据转换出错
# 第16349条数据转换出错
# 第16350条数据转换出错
# 第16351条数据转换出错
# 第16352条数据转换出错
# 第16353条数据转换出错
# 第16354条数据转换出错
# 第16355条数据转换出错
# 第16356条数据转换出错
# 第16357条数据转换出错
# 第16358条数据转换出错
# 第16359条数据转换出错
# 第16360条数据转换出错
# 第16361条数据转换出错
# 第16362条数据转换出错
# 第16363条数据转换出错
# 第16364条数据转换出错
# 第16365条数据转换出错
# 第16366条数据转换出错
# 第16367条数据转换出错
# 第16368条数据转换出错
# 第16369条数据转换出错
# 第16370条数据转换出错
# 第16371条数据转换出错
# 第16372条数据转换出错
# 第16373条数据转换出错
# 第16374条数据转换出错
# 第16375条数据转换出错
# 第16376条数据转换出错
# 第16377条数据转换出错
# 第16378条数据转换出错
# 第16379条数据转换出错
# 第16380条数据转换出错
# 第16381条数据转换出错
#  96%|████████████████████████████████████████████████████████████████████████   | 16382/17058 [00:57<00:02, 281.73it/s]
# 第16382条数据转换出错
# 第16383条数据转换出错
# 第16384条数据转换出错
# 第16385条数据转换出错
# 第16386条数据转换出错
# 第16387条数据转换出错
# 第16388条数据转换出错
# 第16389条数据转换出错
# 第16390条数据转换出错
# 第16391条数据转换出错
# 第16392条数据转换出错
# 第16393条数据转换出错
# 第16394条数据转换出错
# 第16395条数据转换出错
# 第16396条数据转换出错
# 第16397条数据转换出错
# 第16398条数据转换出错
# 第16399条数据转换出错
# 第16400条数据转换出错
# 第16401条数据转换出错
# 第16402条数据转换出错
# 第16403条数据转换出错
# 第16404条数据转换出错
# 第16405条数据转换出错
# 第16406条数据转换出错
# 第16407条数据转换出错
# 第16408条数据转换出错
# 第16409条数据转换出错
# 第16410条数据转换出错
# 第16411条数据转换出错
# 第16412条数据转换出错
#  96%|████████████████████████████████████████████████████████████████████████▏  | 16413/17058 [00:57<00:02, 287.46it/s]
# 第16413条数据转换出错
# 第16414条数据转换出错
# 第16415条数据转换出错
# 第16416条数据转换出错
# 第16417条数据转换出错
# 第16418条数据转换出错
# 第16419条数据转换出错
# 第16420条数据转换出错
# 第16421条数据转换出错
# 第16422条数据转换出错
# 第16423条数据转换出错
# 第16424条数据转换出错
# 第16425条数据转换出错
# 第16426条数据转换出错
# 第16427条数据转换出错
# 第16428条数据转换出错
# 第16429条数据转换出错
# 第16430条数据转换出错
# 第16431条数据转换出错
# 第16432条数据转换出错
# 第16433条数据转换出错
# 第16434条数据转换出错
# 第16435条数据转换出错
# 第16436条数据转换出错
# 第16437条数据转换出错
# 第16438条数据转换出错
# 第16439条数据转换出错
# 第16440条数据转换出错
# 第16441条数据转换出错
# 第16442条数据转换出错
# 第16443条数据转换出错
# 第16444条数据转换出错
# 第16445条数据转换出错
# 第16446条数据转换出错
# 第16447条数据转换出错
# 第16448条数据转换出错
# 第16449条数据转换出错
# 第16450条数据转换出错
# 第16451条数据转换出错
#  96%|████████████████████████████████████████████████████████████████████████▎  | 16452/17058 [00:57<00:01, 307.85it/s]
# 第16452条数据转换出错
# 第16453条数据转换出错
# 第16454条数据转换出错
# 第16455条数据转换出错
# 第16456条数据转换出错
# 第16457条数据转换出错
# 第16458条数据转换出错
# 第16459条数据转换出错
# 第16460条数据转换出错
# 第16461条数据转换出错
# 第16462条数据转换出错
# 第16463条数据转换出错
# 第16464条数据转换出错
# 第16465条数据转换出错
# 第16466条数据转换出错
# 第16467条数据转换出错
# 第16468条数据转换出错
# 第16469条数据转换出错
# 第16470条数据转换出错
# 第16471条数据转换出错
# 第16472条数据转换出错
# 第16473条数据转换出错
# 第16474条数据转换出错
# 第16475条数据转换出错
# 第16476条数据转换出错
# 第16477条数据转换出错
# 第16478条数据转换出错
# 第16479条数据转换出错
# 第16480条数据转换出错
# 第16481条数据转换出错
# 第16482条数据转换出错
# 第16483条数据转换出错
# 第16484条数据转换出错
#  97%|████████████████████████████████████████████████████████████████████████▍  | 16485/17058 [00:57<00:01, 290.41it/s]
# 第16485条数据转换出错
# 第16486条数据转换出错
# 第16487条数据转换出错
# 第16488条数据转换出错
# 第16489条数据转换出错
# 第16490条数据转换出错
# 第16491条数据转换出错
# 第16492条数据转换出错
# 第16493条数据转换出错
# 第16494条数据转换出错
# 第16495条数据转换出错
# 第16496条数据转换出错
# 第16497条数据转换出错
# 第16498条数据转换出错
# 第16499条数据转换出错
# 第16500条数据转换出错
# 第16501条数据转换出错
# 第16502条数据转换出错
# 第16503条数据转换出错
# 第16504条数据转换出错
# 第16505条数据转换出错
# 第16506条数据转换出错
# 第16507条数据转换出错
# 第16508条数据转换出错
# 第16509条数据转换出错
# 第16510条数据转换出错
# 第16511条数据转换出错
# 第16512条数据转换出错
# 第16513条数据转换出错
# 第16514条数据转换出错
# 第16515条数据转换出错
#  97%|████████████████████████████████████████████████████████████████████████▌  | 16516/17058 [00:57<00:01, 288.01it/s]
# 第16516条数据转换出错
# 第16517条数据转换出错
# 第16518条数据转换出错
# 第16519条数据转换出错
# 第16520条数据转换出错
# 第16521条数据转换出错
# 第16522条数据转换出错
# 第16523条数据转换出错
# 第16524条数据转换出错
# 第16525条数据转换出错
# 第16526条数据转换出错
# 第16527条数据转换出错
# 第16528条数据转换出错
# 第16529条数据转换出错
# 第16530条数据转换出错
# 第16531条数据转换出错
# 第16532条数据转换出错
# 第16533条数据转换出错
# 第16534条数据转换出错
# 第16535条数据转换出错
# 第16536条数据转换出错
# 第16537条数据转换出错
# 第16538条数据转换出错
# 第16539条数据转换出错
# 第16540条数据转换出错
# 第16541条数据转换出错
# 第16542条数据转换出错
# 第16543条数据转换出错
# 第16544条数据转换出错
# 第16545条数据转换出错
# 第16546条数据转换出错
# 第16547条数据转换出错
#  97%|████████████████████████████████████████████████████████████████████████▊  | 16548/17058 [00:57<00:01, 296.31it/s]
# 第16548条数据转换出错
# 第16549条数据转换出错
# 第16550条数据转换出错
# 第16551条数据转换出错
# 第16552条数据转换出错
# 第16553条数据转换出错
# 第16554条数据转换出错
# 第16555条数据转换出错
# 第16556条数据转换出错
# 第16557条数据转换出错
# 第16558条数据转换出错
# 第16559条数据转换出错
# 第16560条数据转换出错
# 第16561条数据转换出错
# 第16562条数据转换出错
# 第16563条数据转换出错
# 第16564条数据转换出错
# 第16565条数据转换出错
# 第16566条数据转换出错
# 第16567条数据转换出错
# 第16568条数据转换出错
# 第16569条数据转换出错
# 第16570条数据转换出错
# 第16571条数据转换出错
# 第16572条数据转换出错
# 第16573条数据转换出错
# 第16574条数据转换出错
# 第16575条数据转换出错
# 第16576条数据转换出错
# 第16577条数据转换出错
# 第16578条数据转换出错
#  97%|████████████████████████████████████████████████████████████████████████▉  | 16579/17058 [00:57<00:01, 253.47it/s]
# 第16579条数据转换出错
# 第16580条数据转换出错
# 第16581条数据转换出错
# 第16582条数据转换出错
# 第16583条数据转换出错
# 第16584条数据转换出错
# 第16585条数据转换出错
# 第16586条数据转换出错
# 第16587条数据转换出错
# 第16588条数据转换出错
# 第16589条数据转换出错
# 第16590条数据转换出错
# 第16591条数据转换出错
# 第16592条数据转换出错
# 第16593条数据转换出错
# 第16594条数据转换出错
# 第16595条数据转换出错
# 第16596条数据转换出错
# 第16597条数据转换出错
# 第16598条数据转换出错
# 第16599条数据转换出错
# 第16600条数据转换出错
# 第16601条数据转换出错
# 第16602条数据转换出错
# 第16603条数据转换出错
# 第16604条数据转换出错
# 第16605条数据转换出错
# 第16606条数据转换出错
#  97%|█████████████████████████████████████████████████████████████████████████  | 16607/17058 [00:57<00:01, 258.20it/s]
# 第16607条数据转换出错
# 第16608条数据转换出错
# 第16609条数据转换出错
# 第16610条数据转换出错
# 第16611条数据转换出错
# 第16612条数据转换出错
# 第16613条数据转换出错
# 第16614条数据转换出错
# 第16615条数据转换出错
# 第16616条数据转换出错
# 第16617条数据转换出错
# 第16618条数据转换出错
# 第16619条数据转换出错
# 第16620条数据转换出错
# 第16621条数据转换出错
# 第16622条数据转换出错
# 第16623条数据转换出错
# 第16624条数据转换出错
# 第16625条数据转换出错
# 第16626条数据转换出错
# 第16627条数据转换出错
# 第16628条数据转换出错
# 第16629条数据转换出错
# 第16630条数据转换出错
# 第16631条数据转换出错
# 第16632条数据转换出错
# 第16633条数据转换出错
# 第16634条数据转换出错
# 第16635条数据转换出错
# 第16636条数据转换出错
# 第16637条数据转换出错
# 第16638条数据转换出错
# 第16639条数据转换出错
# 第16640条数据转换出错
# 第16641条数据转换出错
# 第16642条数据转换出错
# 第16643条数据转换出错
# 第16644条数据转换出错
# 第16645条数据转换出错
# 第16646条数据转换出错
# 第16647条数据转换出错
# 第16648条数据转换出错
# 第16649条数据转换出错
#  98%|█████████████████████████████████████████████████████████████████████████▏ | 16650/17058 [00:58<00:01, 292.92it/s]
# 第16650条数据转换出错
# 第16651条数据转换出错
# 第16652条数据转换出错
# 第16653条数据转换出错
# 第16654条数据转换出错
# 第16655条数据转换出错
# 第16656条数据转换出错
# 第16657条数据转换出错
# 第16658条数据转换出错
# 第16659条数据转换出错
# 第16660条数据转换出错
# 第16661条数据转换出错
# 第16662条数据转换出错
# 第16663条数据转换出错
# 第16664条数据转换出错
# 第16665条数据转换出错
# 第16666条数据转换出错
# 第16667条数据转换出错
# 第16668条数据转换出错
# 第16669条数据转换出错
# 第16670条数据转换出错
# 第16671条数据转换出错
# 第16672条数据转换出错
# 第16673条数据转换出错
# 第16674条数据转换出错
# 第16675条数据转换出错
# 第16676条数据转换出错
# 第16677条数据转换出错
# 第16678条数据转换出错
# 第16679条数据转换出错
# 第16680条数据转换出错
# 第16681条数据转换出错
# 第16682条数据转换出错
# 第16683条数据转换出错
# 第16684条数据转换出错
# 第16685条数据转换出错
#  98%|█████████████████████████████████████████████████████████████████████████▎ | 16686/17058 [00:58<00:01, 309.68it/s]
# 第16686条数据转换出错
# 第16687条数据转换出错
# 第16688条数据转换出错
# 第16689条数据转换出错
# 第16690条数据转换出错
# 第16691条数据转换出错
# 第16692条数据转换出错
# 第16693条数据转换出错
# 第16694条数据转换出错
# 第16695条数据转换出错
# 第16696条数据转换出错
# 第16697条数据转换出错
# 第16698条数据转换出错
# 第16699条数据转换出错
# 第16700条数据转换出错
# 第16701条数据转换出错
# 第16702条数据转换出错
# 第16703条数据转换出错
# 第16704条数据转换出错
# 第16705条数据转换出错
# 第16706条数据转换出错
# 第16707条数据转换出错
# 第16708条数据转换出错
# 第16709条数据转换出错
# 第16710条数据转换出错
# 第16711条数据转换出错
# 第16712条数据转换出错
# 第16713条数据转换出错
# 第16714条数据转换出错
# 第16715条数据转换出错
# 第16716条数据转换出错
# 第16717条数据转换出错
# 第16718条数据转换出错
#  98%|█████████████████████████████████████████████████████████████████████████▌ | 16719/17058 [00:58<00:01, 290.78it/s]
# 第16719条数据转换出错
# 第16720条数据转换出错
# 第16721条数据转换出错
# 第16722条数据转换出错
# 第16723条数据转换出错
# 第16724条数据转换出错
# 第16725条数据转换出错
# 第16726条数据转换出错
# 第16727条数据转换出错
# 第16728条数据转换出错
# 第16729条数据转换出错
# 第16730条数据转换出错
# 第16731条数据转换出错
# 第16732条数据转换出错
# 第16733条数据转换出错
# 第16734条数据转换出错
# 第16735条数据转换出错
# 第16736条数据转换出错
# 第16737条数据转换出错
# 第16738条数据转换出错
# 第16739条数据转换出错
# 第16740条数据转换出错
# 第16741条数据转换出错
# 第16742条数据转换出错
# 第16743条数据转换出错
# 第16744条数据转换出错
# 第16745条数据转换出错
# 第16746条数据转换出错
# 第16747条数据转换出错
# 第16748条数据转换出错
# 第16749条数据转换出错
#  98%|█████████████████████████████████████████████████████████████████████████▋ | 16750/17058 [00:58<00:01, 288.27it/s]
# 第16750条数据转换出错
# 第16751条数据转换出错
# 第16752条数据转换出错
# 第16753条数据转换出错
# 第16754条数据转换出错
# 第16755条数据转换出错
# 第16756条数据转换出错
# 第16757条数据转换出错
# 第16758条数据转换出错
# 第16759条数据转换出错
# 第16760条数据转换出错
# 第16761条数据转换出错
# 第16762条数据转换出错
# 第16763条数据转换出错
# 第16764条数据转换出错
# 第16765条数据转换出错
# 第16766条数据转换出错
# 第16767条数据转换出错
# 第16768条数据转换出错
# 第16769条数据转换出错
# 第16770条数据转换出错
# 第16771条数据转换出错
# 第16772条数据转换出错
# 第16773条数据转换出错
# 第16774条数据转换出错
# 第16775条数据转换出错
# 第16776条数据转换出错
# 第16777条数据转换出错
# 第16778条数据转换出错
# 第16779条数据转换出错
#  98%|█████████████████████████████████████████████████████████████████████████▊ | 16780/17058 [00:58<00:01, 277.38it/s]
# 第16780条数据转换出错
# 第16781条数据转换出错
# 第16782条数据转换出错
# 第16783条数据转换出错
# 第16784条数据转换出错
# 第16785条数据转换出错
# 第16786条数据转换出错
# 第16787条数据转换出错
# 第16788条数据转换出错
# 第16789条数据转换出错
# 第16790条数据转换出错
# 第16791条数据转换出错
# 第16792条数据转换出错
# 第16793条数据转换出错
# 第16794条数据转换出错
# 第16795条数据转换出错
# 第16796条数据转换出错
# 第16797条数据转换出错
# 第16798条数据转换出错
# 第16799条数据转换出错
# 第16800条数据转换出错
# 第16801条数据转换出错
# 第16802条数据转换出错
# 第16803条数据转换出错
# 第16804条数据转换出错
# 第16805条数据转换出错
# 第16806条数据转换出错
# 第16807条数据转换出错
# 第16808条数据转换出错
#  99%|█████████████████████████████████████████████████████████████████████████▉ | 16809/17058 [00:58<00:01, 239.56it/s]
# 第16809条数据转换出错
# 第16810条数据转换出错
# 第16811条数据转换出错
# 第16812条数据转换出错
# 第16813条数据转换出错
# 第16814条数据转换出错
# 第16815条数据转换出错
# 第16816条数据转换出错
# 第16817条数据转换出错
# 第16818条数据转换出错
# 第16819条数据转换出错
# 第16820条数据转换出错
# 第16821条数据转换出错
# 第16822条数据转换出错
# 第16823条数据转换出错
# 第16824条数据转换出错
# 第16825条数据转换出错
# 第16826条数据转换出错
# 第16827条数据转换出错
# 第16828条数据转换出错
# 第16829条数据转换出错
# 第16830条数据转换出错
# 第16831条数据转换出错
# 第16832条数据转换出错
# 第16833条数据转换出错
# 第16834条数据转换出错
# 第16835条数据转换出错
# 第16836条数据转换出错
# 第16837条数据转换出错
# 第16838条数据转换出错
# 第16839条数据转换出错
# 第16840条数据转换出错
# 第16841条数据转换出错
# 第16842条数据转换出错
#  99%|██████████████████████████████████████████████████████████████████████████ | 16843/17058 [00:58<00:00, 261.80it/s]
# 第16843条数据转换出错
# 第16844条数据转换出错
# 第16845条数据转换出错
# 第16846条数据转换出错
# 第16847条数据转换出错
# 第16848条数据转换出错
# 第16849条数据转换出错
# 第16850条数据转换出错
# 第16851条数据转换出错
# 第16852条数据转换出错
# 第16853条数据转换出错
# 第16854条数据转换出错
# 第16855条数据转换出错
# 第16856条数据转换出错
# 第16857条数据转换出错
# 第16858条数据转换出错
# 第16859条数据转换出错
# 第16860条数据转换出错
# 第16861条数据转换出错
# 第16862条数据转换出错
# 第16863条数据转换出错
# 第16864条数据转换出错
# 第16865条数据转换出错
# 第16866条数据转换出错
# 第16867条数据转换出错
# 第16868条数据转换出错
# 第16869条数据转换出错
# 第16870条数据转换出错
#  99%|██████████████████████████████████████████████████████████████████████████▏| 16871/17058 [00:58<00:00, 252.78it/s]
# 第16871条数据转换出错
# 第16872条数据转换出错
# 第16873条数据转换出错
# 第16874条数据转换出错
# 第16875条数据转换出错
# 第16876条数据转换出错
# 第16877条数据转换出错
# 第16878条数据转换出错
# 第16879条数据转换出错
# 第16880条数据转换出错
# 第16881条数据转换出错
# 第16882条数据转换出错
# 第16883条数据转换出错
# 第16884条数据转换出错
# 第16885条数据转换出错
# 第16886条数据转换出错
# 第16887条数据转换出错
# 第16888条数据转换出错
# 第16889条数据转换出错
# 第16890条数据转换出错
# 第16891条数据转换出错
# 第16892条数据转换出错
# 第16893条数据转换出错
# 第16894条数据转换出错
# 第16895条数据转换出错
# 第16896条数据转换出错
# 第16897条数据转换出错
# 第16898条数据转换出错
# 第16899条数据转换出错
# 第16900条数据转换出错
# 第16901条数据转换出错
#  99%|██████████████████████████████████████████████████████████████████████████▎| 16902/17058 [00:58<00:00, 266.40it/s]
# 第16902条数据转换出错
# 第16903条数据转换出错
# 第16904条数据转换出错
# 第16905条数据转换出错
# 第16906条数据转换出错
# 第16907条数据转换出错
# 第16908条数据转换出错
# 第16909条数据转换出错
# 第16910条数据转换出错
# 第16911条数据转换出错
# 第16912条数据转换出错
# 第16913条数据转换出错
# 第16914条数据转换出错
# 第16915条数据转换出错
# 第16916条数据转换出错
# 第16917条数据转换出错
# 第16918条数据转换出错
# 第16919条数据转换出错
# 第16920条数据转换出错
# 第16921条数据转换出错
# 第16922条数据转换出错
# 第16923条数据转换出错
# 第16924条数据转换出错
# 第16925条数据转换出错
# 第16926条数据转换出错
# 第16927条数据转换出错
# 第16928条数据转换出错
# 第16929条数据转换出错
# 第16930条数据转换出错
# 第16931条数据转换出错
# 第16932条数据转换出错
# 第16933条数据转换出错
# 第16934条数据转换出错
#  99%|██████████████████████████████████████████████████████████████████████████▍| 16935/17058 [00:59<00:00, 280.79it/s]
# 第16935条数据转换出错
# 第16936条数据转换出错
# 第16937条数据转换出错
# 第16938条数据转换出错
# 第16939条数据转换出错
# 第16940条数据转换出错
# 第16941条数据转换出错
# 第16942条数据转换出错
# 第16943条数据转换出错
# 第16944条数据转换出错
# 第16945条数据转换出错
# 第16946条数据转换出错
# 第16947条数据转换出错
# 第16948条数据转换出错
# 第16949条数据转换出错
# 第16950条数据转换出错
# 第16951条数据转换出错
# 第16952条数据转换出错
# 第16953条数据转换出错
# 第16954条数据转换出错
# 第16955条数据转换出错
# 第16956条数据转换出错
# 第16957条数据转换出错
# 第16958条数据转换出错
# 第16959条数据转换出错
# 第16960条数据转换出错
# 第16961条数据转换出错
# 第16962条数据转换出错
# 第16963条数据转换出错
# 第16964条数据转换出错
#  99%|██████████████████████████████████████████████████████████████████████████▌| 16965/17058 [00:59<00:00, 275.48it/s]
# 第16965条数据转换出错
# 第16966条数据转换出错
# 第16967条数据转换出错
# 第16968条数据转换出错
# 第16969条数据转换出错
# 第16970条数据转换出错
# 第16971条数据转换出错
# 第16972条数据转换出错
# 第16973条数据转换出错
# 第16974条数据转换出错
# 第16975条数据转换出错
# 第16976条数据转换出错
# 第16977条数据转换出错
# 第16978条数据转换出错
# 第16979条数据转换出错
# 第16980条数据转换出错
# 第16981条数据转换出错
# 第16982条数据转换出错
# 第16983条数据转换出错
# 第16984条数据转换出错
# 第16985条数据转换出错
# 第16986条数据转换出错
# 第16987条数据转换出错
# 第16988条数据转换出错
# 第16989条数据转换出错
# 第16990条数据转换出错
# 第16991条数据转换出错
# 第16992条数据转换出错
# 第16993条数据转换出错
# 100%|██████████████████████████████████████████████████████████████████████████▋| 16994/17058 [00:59<00:00, 239.15it/s]
# 第16994条数据转换出错
# 第16995条数据转换出错
# 第16996条数据转换出错
# 第16997条数据转换出错
# 第16998条数据转换出错
# 第16999条数据转换出错
# 第17000条数据转换出错
# 第17001条数据转换出错
# 第17002条数据转换出错
# 第17003条数据转换出错
# 第17004条数据转换出错
# 第17005条数据转换出错
# 第17006条数据转换出错
# 第17007条数据转换出错
# 第17008条数据转换出错
# 第17009条数据转换出错
# 第17010条数据转换出错
# 第17011条数据转换出错
# 第17012条数据转换出错
# 第17013条数据转换出错
# 第17014条数据转换出错
# 第17015条数据转换出错
# 第17016条数据转换出错
# 第17017条数据转换出错
# 第17018条数据转换出错
# 第17019条数据转换出错
# 第17020条数据转换出错
# 第17021条数据转换出错
# 第17022条数据转换出错
# 第17023条数据转换出错
# 第17024条数据转换出错
# 第17025条数据转换出错
# 第17026条数据转换出错
# 第17027条数据转换出错
# 第17028条数据转换出错
# 第17029条数据转换出错
# 第17030条数据转换出错
# 第17031条数据转换出错
# 100%|██████████████████████████████████████████████████████████████████████████▉| 17032/17058 [00:59<00:00, 268.66it/s]
# 第17032条数据转换出错
# 第17033条数据转换出错
# 第17034条数据转换出错
# 第17035条数据转换出错
# 第17036条数据转换出错
# 第17037条数据转换出错
# 第17038条数据转换出错
# 第17039条数据转换出错
# 第17040条数据转换出错
# 第17041条数据转换出错
# 第17042条数据转换出错
# 第17043条数据转换出错
# 第17044条数据转换出错
# 第17045条数据转换出错
# 第17046条数据转换出错
# 第17047条数据转换出错
# 第17048条数据转换出错
# 第17049条数据转换出错
# 第17050条数据转换出错
# 第17051条数据转换出错
# 第17052条数据转换出错
# 第17053条数据转换出错
# 第17054条数据转换出错
# 第17055条数据转换出错
# 第17056条数据转换出错
# 第17057条数据转换出错
# 100%|███████████████████████████████████████████████████████████████████████████| 17058/17058 [00:59<00:00, 286.48it/s]

# %% [markdown]
# #### 经纬度热力图

# %%
# %%html
# <img src='./img/geo.png', width=80%>
# Out:
# <img src='./img/geo.png', width=80%>

# %% [markdown]
# ### 2.缺失值处理

# %%
# 发现存在缺失信息较多的房源，接下来进行筛选后删除
# 删除总价及单价均为空的数据
data.drop(index=data[(data['total'].isnull()) & (data['unit'].isnull())].index, inplace=True)
# 筛选并保留缺失比例小于50
tmp_df = data[['name', 'address', 'model', 'area', 'direct', 'perfect', 'floor','year','type', 'traffic']]
rows_null = tmp_df.isnull().sum(axis=1) / len(tmp_df.columns)
data = data.loc[rows_null < 0.5, :]

# %%
#用众数填补年份特征的缺失值
yearMode=data['year'].mode()[0]
data['year']=data['year'].fillna(yearMode)

# %%
#处理交通特征缺失值
data['traffic'].fillna('无地铁',inplace=True)

# %% [markdown]
# ### 3.异常值处理

# %%
#处理年份异常值,用众数替换异常值
re=r'\D'
yearMode=data['year'].mode()[0]
data['year'][data['year'].str.contains(re)]=yearMode

# %%
#处理户型异常值,将0室改为1室
sh=r'^0'
data['model']=data['model'].str.replace(sh,'1')

# %% [markdown]
# # 特征工程以及可视化

# %% [markdown]
# ### 1.数据转换

# %%
#处理价格特征
data['unit']=round(data['unit'].apply(lambda x:int(x.split('价')[1].split('元')[0]))/10000,1)

# %%
#单价分布图
sns.distplot(data['unit'])
plt.show()
#房价分布为偏态分布，非正太分布，后面可以考虑转换成正太分布

# %%
#处理面积特征
data['area']=data['area'].apply(lambda x: x.split('平')[0]).astype('float64')

# %%
#处理户型特征
data['室']=data['model'].apply(lambda x : x.split('室')[0]).astype('int64')
data['厅']=data['model'].apply(lambda x : x.split('厅')[0].split('室')[1]).astype('int64')

# %%
# 查看年份分布
data['year'].value_counts().plot(kind='bar', figsize=(18, 9), rot=45, fontsize=15)
plt.show()

# %%
#处理时间特征
data['year']=data['year'].astype('int64')
#最近的年份减每个年份
data['yearNum']=data['year'].max()-data['year']

# %%
#独热编码处理特征
oneHot=['direct','perfect','floor','type','traffic']

# %%
#处理方位特征
def transDir(df):
    #空列表
    tempList=[]
    dirList=df['direct'].str.split(' ').tolist()
    #方位字典
    dirDict={'东':0,'南':0,'西':0,'北':0,'东北':0,'东南':0,'西北':0,'西南':0}
    for i in tqdm(range(df.shape[0])):
        for item in dirList[i]:
            if item in dirDict:
                dirDict[item]+=1
        tempList.append(dirDict)
        #初始化字典
        dirDict={'东':0,'南':0,'西':0,'北':0,'东北':0,'东南':0,'西北':0,'西南':0}
    return tempList

# %%
tempDf=transDir(data)
#转化为Df格式
dirDf=pd.DataFrame(tempDf)
#与源数据合并
data=pd.concat([data,dirDf],axis=1)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 17058/17058 [00:00<00:00, 777534.99it/s]

# %%
#处理楼层特征
#低于15楼的归于低楼层，15到30为中楼层，30以上为高楼层
def judge_floor(num):
    if num<15:
        floor='低楼层'
    elif 15<=num<30:
        floor='中楼层'
    else:
        floor='高楼层'
    return floor

# %%
#转化
def trans_floor(df):
    td=df['floor'].apply(lambda x:x.split('(')[0])
    #正则表达式
    gk=r'^\d'
    td[td.str.contains(gk)]=td[td.str.contains(gk)].apply(lambda x:x.split('层')[0]).apply(lambda x:judge_floor(int(x)))
    return td

# %%
data['floorNew']=trans_floor(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-1f3515e6b430> in <module>
# ----> 1 data['floorNew']=trans_floor(data)
#
# <ipython-input-27-20582da2bfa8> in trans_floor(df)
#       1 #转化
#       2 def trans_floor(df):
# ----> 3     td=df['floor'].apply(lambda x:x.split('(')[0])
#       4     #正则表达式
#       5     gk=r'^\d'
#
# D:\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-27-20582da2bfa8> in <lambda>(x)
#       1 #转化
#       2 def trans_floor(df):
# ----> 3     td=df['floor'].apply(lambda x:x.split('(')[0])
#       4     #正则表达式
#       5     gk=r'^\d'
#
# AttributeError: 'float' object has no attribute 'split'

# %%
#处理楼层特征
#独热编码处理特征
oneHot=['address','perfect','floorNew','type','traffic']
def get_oneHot(df,oneHotList):
    for item in oneHotList:
        #独热编码
        tempDf=pd.get_dummies(df[item])
        #重命名
        for i in range(tempDf.columns.shape[0]):
            tempDf.rename(columns={tempDf.columns[i]:item+'_'+str(i)},inplace=True)
        #合并
        df=pd.concat([df,tempDf],axis=1)
    return df

# %%
data=get_oneHot(data,oneHot)

# %% [markdown]
# # 分别求每个房源指定范围内学校、医院、商场的数量
# # 使用apply函数对以上三种场所进行距离计算，并取5km范围内数量
# # 经纬度距离计算转化为km：使用geopy进行距离计算
# # 使用经纬度进行特征扩充，计算指定距离范围(单位:km)内学校、医院、商场数量

# %%
# 重点学校、医院、商场地理坐标，通过常量存储
kp_schcool = {'幼儿园':{'厦门毅康幼儿园':(24.510597, 118.11754),
                        '厦门市海城幼儿园':(24.474125, 118.099648),
                        '厦门市湖里区南泰苑特房艺术幼儿园':(24.508546, 118.1114),
                        '厦门市金鸡亭幼儿园':(24.480669, 118.151603),
                        '厦门市第九幼儿园':(24.481007, 118.114035),
                        '厦门市鼓浪屿日光幼儿园':(24.449937, 118.073416),
                        '厦门市振兴幼儿园':(24.485166, 118.099807),
                        '厦门市蓝天幼儿园':(24.500507, 118.151464),
                        '厦门市仙岳幼儿园':(24.497445, 118.10177),
                        '厦门莲龙幼儿园':(24.494872, 118.145078)},
              '小学':{'厦门市集美小学':(24.575549, 118.105817),
                        '厦门市滨东小学':(24.482332, 118.115181,),
                        '厦门外国语学校附属小学':(24.479366, 118.108217),
                        '厦门同安第一实验小学':(24.737489, 118.163726),
                        '厦门第二实验小学':(24.488178, 118.13328),
                        '厦门市槟榔小学':(24.486965, 118.117595),
                        '厦门市民立小学':(24.460889, 118.082973),
                        '厦门市实验小学':(24.461625, 118.095239),
                        '厦门市演武小学':(24.444945, 118.09853)},
              '中学':{'厦门市双十中学':(24.522979, 118.161578),
                        '厦门市外国语学校':(24.483883, 118.09878),
                        '厦门市第一中学':(24.465068, 118.105468),
                        '厦门市第十一中学':(24.472203, 118.091047),
                        '厦门市松柏中学':(24.496271, 118.124842),
                        '厦门市第六中学':(24.466131, 118.088328),
                        '厦门市同安一中':(24.744241, 118.163146),
                        '厦门市莲花中学':(24.489817, 118.135714),
                        '厦门市集美中学':(24.601198, 118.121767),
                        }}
kp_hospital = {'厦门市眼科中心':(24.514054, 118.197927),
                '厦门市仙岳医院':(24.501499, 118.117878),
                '厦门大学附属厦门眼科中心':(24.466303, 118.087465),
                '解放军第一七四医院':(24.465084, 118.101848),
                '厦门大学附属中山医院':(24.477694, 118.104437),
                '厦门大学附属翔安医院':(24.593282, 118.27267),
                '厦门长庚医院':(24.540208, 118.015807),
                '厦门市精神卫生中心':(24.508779, 118.1141),
                '厦门市第三医院':(24.711822, 118.153719),
                '厦门市第二医院':(24.590336, 118.11087),
                }
kp_mall = {'SM城市广场':(24.50701, 118.13372),
            '万象城MIXC':(24.478183, 118.117889),
            '宝龙一城':(24.492034, 118.178751),
            '湖里万达广场':(24.510421, 118.183849),
            '罗宾森广场':(24.474916, 118.119239),
            '建发湾悦城':(24.521607, 118.167925),
            '世茂Emall':(24.442476, 118.094721),
            '磐基名品中心':(24.488179, 118.126967),
            '老虎城欢乐购物中心':(24.459434, 118.087391)
            }

# %%
def get_thre_num(house_geo, geo_list, threshold=5):
    num_cnt = 0
    for geo_value in geo_list.values():
        if geodesic(house_geo, geo_value).km < threshold:
            num_cnt += 1
    return num_cnt

# %%
data['geo'] = tuple(zip(data['纬度'], data['经度']))

# %%
# 学校
data['5公里内重点幼儿园数量'] = data['geo'].apply(get_thre_num, args=(kp_schcool['幼儿园'], 5))
data['5公里内重点小学数量'] = data['geo'].apply(get_thre_num, args=(kp_schcool['小学'], 5))
data['5公里内重点中学数量'] = data['geo'].apply(get_thre_num, args=(kp_schcool['中学'], 5))
# 医院
data['5公里内重点医院数量'] = data['geo'].apply(get_thre_num, args=(kp_hospital, 5))
# 商场
data['5公里内重点商场数量'] = data['geo'].apply(get_thre_num, args=(kp_mall, 5))

# %%
#删除无用特征
df=data.drop(columns=['ID','name','address','model','area','direct','perfect','floor','floorNew','year','type','traffic','total','geo'])

# %%
#将uint8类型转为int64类型
for col in df.columns:
    if df[col].dtype=='uint8':
        df[col]=df[col].astype('int64')

# %% [markdown]
# # 建模分析

# %%
#划分训练集和测试集
df_train = df.iloc[:int(len(df)*0.9), :]
df_test = df.iloc[int(len(df)*0.9):, :]

# %%
#划分标签
train_X,train_Y=df_train.drop(columns='unit'),df_train['unit']
test_X,test_Y=df_test.drop(columns='unit'),df_test['unit']

# %%
#用xgboost 进行3折交叉验证
param={
    
    'learning_rate':0.3,
    'n_estimators':250,
    'eta':0.1,
    'max_depth':8,
    'alpha':0.1,
    'lambda':0.1,
    'subsample':0.8
    
}

oof = np.zeros(len(df_train))
predictions = np.zeros(len(df_test))
feature_importance_df = pd.DataFrame()

xgbr= XGBRegressor(learning_rate=0.3,n_estimators=500,eta=0.1,max_depth=8)
kf = KFold(n_splits=3, random_state=2020, shuffle=True)

#交叉训练模型

for fold_, (trn_idx, val_idx) in enumerate(kf.split(df_train)):
    print("fold {}".format(fold_))
    # 训练集
    train_data = train_X.iloc[trn_idx,:]
    train_label = train_Y.iloc[trn_idx]
    # 验证集
    valid_data = train_X.iloc[val_idx,:]
    valid_label = train_Y.iloc[val_idx]
    
    xgbr.fit(train_data,train_label)
    oof[val_idx] = xgbr.predict(valid_data)
    
    #统计特征重要性因子
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = train_X.columns
    fold_importance_df["importance"] = xgbr.feature_importances_
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    #测试集结果
    predictions += xgbr.predict(test_X) / kf.n_splits

# %%
feature_importance_df = feature_importance_df.groupby(by=['Feature'], as_index=False)['importance'].agg('mean').reset_index(drop=True)
feature_importance_df.sort_values(by='importance', ascending=False, inplace=True)

# %%
#选取重要程度最高的前20个特征
importance_df=feature_importance_df.sort_values(by='importance',ascending=False).iloc[:21,:]

# %%
#特征重要性分布图
plt.figure(figsize=(16, 9))
fig= sns.barplot(x='Feature', y='importance', data=importance_df)
fig.set_xticklabels(labels=importance_df['Feature'].values, rotation=80, size=15)
plt.show()

# %%
# 模型在测试集上的表现
results = xgbr.predict(test_X)
mseScroe=mean_squared_error(test_Y,predictions)
maeScroe=mean_absolute_error(test_Y,predictions)
r2Scroe=r2_score(test_Y,predictions)
print('rmse_score:{:.4f};'.format(mseScroe**0.5))
print('mae_score:{:.4f};'.format(maeScroe))
print('r2_score:{:.4f};'.format(r2Scroe))

# %%
plt.figure(figsize=(18, 9))
plt.plot(list(range(len(test_X))), test_Y, "-o", label='真实值')
plt.plot(list(range(len(test_Y))), results, "--o", label='预测值')
plt.legend()
# 展现画布
plt.show()

# %%
from sklearn.metrics import r2_score

# %%
# 经纬度
import folium
from folium.plugins import HeatMap

geo_center = [24.5580803, 118.0747703]
geo_map = folium.Map(location=geo_center, zoom_start=13.5)

heatdata = ori_df[['纬度', '经度', '单价']].values.tolist()

HeatMap(heatdata, radius=7).add_to(geo_map) # gradient={.4:'blue',.65:'yellow',1:'red'}

geo_map
